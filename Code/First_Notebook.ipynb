# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import pandas as pd

# %%
raw_data = np.loadtxt('/Users/samsonmercier/Desktop/Work/PhD/Research/Second Generals/Data/training_data_Tp.csv', delimiter=',')
raw_inputs = raw_data[:, :5]
raw_outputs = raw_data[:, 5:]

# %%
P_grid = np.linspace(0, 2, 51)

# %%
for raw_output in raw_outputs:
    fig, ax = plt.subplots(1, 1, figsize=[8, 6])
    ax.plot(raw_output, np.log(P_grid), color='blue', alpha=0.2)
    ax.invert_yaxis()
    plt.show()
