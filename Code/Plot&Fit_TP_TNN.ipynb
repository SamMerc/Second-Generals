# %% [markdown]
# # Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

# %% [markdown]
# # Import raw data

# %%
#File containing temperature values
raw_T_data = np.loadtxt('/Users/samsonmercier/Desktop/Work/PhD/Research/Second_Generals/Data/bt-4500k/training_data_T.csv', delimiter=',')
#File containing pressure values
raw_P_data = np.loadtxt('/Users/samsonmercier/Desktop/Work/PhD/Research/Second_Generals/Data/bt-4500k/training_data_P.csv', delimiter=',')

#Last 51 columns are the temperature/pressure values, 
#First 5 are the input values (H2 pressure in bar, CO2 pressure in bar, LoD in hours, Obliquity in deg, H2+Co2 pressure) but we remove the last one since it's not adding info.
raw_inputs = raw_T_data[:, :4]
raw_outputs_T = raw_T_data[:, 5:]
raw_outputs_P = raw_P_data[:, 5:]

#Storing useful quantitites
N = raw_inputs.shape[0] #Number of data points
D = raw_inputs.shape[1] #Number of features
O = raw_outputs_T.shape[1] #Number of outputs

# %% [markdown]
# # Plotting of the T-P profiles

# %%
for raw_input, raw_output_T, raw_output_P in zip(raw_inputs,raw_outputs_T,raw_outputs_P):
    fig, ax = plt.subplots(1, 1, figsize=[8, 6])
    ax.plot(raw_output_T, np.log(raw_output_P/1000), color='blue', linewidth=2)
    ax.invert_yaxis()
    ax.set_xlabel('Temperature (K)')
    ax.set_ylabel(r'log$_{10}$ Pressure (bar)')
    ax.set_title(rf'H$_2$O : {raw_input[0]} bar, CO$_2$ : {raw_input[1]} bar, LoD : {raw_input[2]:.0f} days, Obliquity : {raw_input[3]} deg')
    plt.show()

# %% [markdown]
# # Fitting the training data with a transformer neural network

# %% [markdown]
# ## 0th step : Shrink down data so we can work with it locally

# %%
#Number of samples to shrink our dataset to 
sample_size = 100

filter = np.random.choice(np.arange(N), size=sample_size, replace=False)

raw_inputs = torch.tensor(raw_inputs[filter, :], dtype=torch.float32)
raw_outputs_T = torch.tensor(raw_outputs_T[filter, :], dtype=torch.float32)
raw_outputs_P = torch.tensor(raw_outputs_P[filter, :], dtype=torch.float32)

N = sample_size

# %% [markdown]
# ## First step : Define a training, validation, and testing set

# %%
#Defining partition of data used for 1. training 2. validation and 3. testing
data_partitions = [0.7, 0.1, 0.2]

#Defining the noise seed for the random partitioning of the training data
partition_seed = 4

#Splitting the data 
## Setting noise seec
generator = torch.Generator().manual_seed(partition_seed)
## Retrieving indices of data partitions
train_idx, valid_idx, test_idx = torch.utils.data.random_split(range(N), data_partitions, generator=generator)
## Generate the data partitions
### Training
train_inputs = raw_inputs[train_idx]
train_outputs_T = raw_outputs_T[train_idx]
train_outputs_P = raw_outputs_P[train_idx]
### Validation
valid_inputs = raw_inputs[valid_idx]
valid_outputs_T = raw_outputs_T[valid_idx]
valid_outputs_P = raw_outputs_P[valid_idx]
### Testing
test_inputs = raw_inputs[test_idx]
test_outputs_T = raw_outputs_T[test_idx]
test_outputs_P = raw_outputs_P[test_idx]

# %% [markdown]
# ## Second step : defining the transformer NN

# %%
# ---------------------
# Defining transformer hyper-parameters
# ---------------------
## Number of attention heads
att_heads = 16
## Number of encoder/decoder layers 
num_layers = 12
## Dimensionality of internal embeddings (i.e. transformer width)
d_model = 64
## Dimension of the feedforward network model (i.e. size of hidden layer)
dim_feedforward = 128
## Number of inputs
src_len = 4
## Number of outputs
tgt_len = 51

# ---------------------
# Defining the model
# ---------------------
## Layers
src_embed = torch.nn.Linear(1, d_model)   # for 4 inputs as a sequence
tgt_embed = torch.nn.Linear(1, d_model)   # for 51 outputs as a sequence
out_proj  = torch.nn.Linear(d_model, 1)   # back to scalar temps

src_pos = torch.nn.Parameter(torch.randn(1, src_len, d_model))
tgt_pos = torch.nn.Parameter(torch.randn(1, tgt_len, d_model))

transformer = torch.nn.Transformer(
    d_model=d_model,
    nhead=att_heads,
    num_encoder_layers=num_layers,
    num_decoder_layers=num_layers,
    dim_feedforward=dim_feedforward,
    batch_first=True
)

criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(list(src_embed.parameters()) +
                       list(tgt_embed.parameters()) +
                       list(out_proj.parameters()) +
                       [src_pos, tgt_pos] +
                       list(transformer.parameters()), lr=1e-3)

# %% [markdown]
# ## Third step: running the training

# %%
# ----------------------------
# Training and validation loop
# ----------------------------
train_losses, val_losses = [], []
epochs = 5000

for epoch in range(epochs):
    # ---- TRAIN ----
    #Telling PyTorch we are in training mode
    transformer.train()
    #Resets accumulated gradients - otherwise you stack onto the previous gradient values
    optimizer.zero_grad()

    #Transformer expects 3D tensor (batch size, sequence length, embedding size) so we add an extra dimension
    src = train_inputs.float().unsqueeze(-1)  # (N,4,1)
    #Pass each scalar input through linear embedding layer
    src = src_embed(src) + src_pos

    #Load target T-P profiles for the current batch
    Y_in = train_outputs_T.float()
    #Adds the extra dimension
    tgt = Y_in.unsqueeze(-1)
    #Projects output temp. values in necessary dimensions
    tgt = tgt_embed(tgt) + tgt_pos

    #Feed source (input) and target (output) into the transformer
    h = transformer(src, tgt)
    #Apply final linear lyaer to convert hidden vector into scalar predicted temp.
    Y_pred = out_proj(h).squeeze(-1)

    #Compute the MSE between predicted and input T-P profile
    train_loss = criterion(Y_pred, Y_in)
    #Runs backpropagation i.e. computes gradients for all weights in network
    train_loss.backward()
    #Updates parameters using computed gradients (in this case with Adam)
    optimizer.step()

    # ---- VALIDATION ----
    #Switch Transformer to evaluation mode
    transformer.eval()
    #Turn off gradient tracking within this block
    with torch.no_grad():

        #Same steps in terms of dimension modification as in training but with validation data
        src = valid_inputs.float().unsqueeze(-1)
        src = src_embed(src) + src_pos

        #Prepare validation targets as decoder input embeddings
        Y_in = valid_outputs_T.float()
        tgt = Y_in.unsqueeze(-1)
        tgt = tgt_embed(tgt) + tgt_pos

        #Runs a pass through the current transformer and generates prediction temperature values
        h = transformer(src, tgt)
        Y_pred_val = out_proj(h).squeeze(-1)

        #Compare predicted T-P profile to validation ones
        val_loss = criterion(Y_pred_val, Y_in)

    #Store training loss and validation loss at each epoch
    train_losses.append(train_loss.item())
    val_losses.append(val_loss.item())

    print(f"Epoch {epoch+1:03d} | Train Loss: {train_loss.item():.4f} | Val Loss: {val_loss.item():.4f}")

# ---- TESTING ----
#Switching the transformer mode to testing/evaluation
transformer.eval()

#Turn off gradient tracking within this block
with torch.no_grad():
    
    #Same steps in terms of dimension modification as in training but with testing data
    src = test_inputs.float().unsqueeze(-1)
    src = src_embed(src) + src_pos

    #Prepare testing targets as decoder input embeddings
    Y_in = torch.zeros_like(test_outputs_T.float())  # zero decoder input
    tgt = Y_in.unsqueeze(-1)
    tgt = tgt_embed(tgt) + tgt_pos

    #Runs a pass through the current transformer and generates prediction temperature values
    h = transformer(src, tgt)
    Y_pred_test = out_proj(h).squeeze(-1)

# Convert temperature outputs to numpy
Y_pred = Y_pred_test.numpy()
# Out:
# Epoch 001 | Train Loss: 48313.2500 | Val Loss: 43679.6641
# Epoch 002 | Train Loss: 47285.2227 | Val Loss: 43306.2344
# Epoch 003 | Train Loss: 46917.3867 | Val Loss: 43136.1406
# Epoch 004 | Train Loss: 46738.3633 | Val Loss: 43032.3906
# Epoch 005 | Train Loss: 46622.3867 | Val Loss: 42967.8906
# Epoch 006 | Train Loss: 46547.5508 | Val Loss: 42916.1328
# Epoch 007 | Train Loss: 46484.2578 | Val Loss: 42870.4219
# Epoch 008 | Train Loss: 46433.7852 | Val Loss: 42831.0391
# Epoch 009 | Train Loss: 46388.8594 | Val Loss: 42795.5195
# Epoch 010 | Train Loss: 46349.2578 | Val Loss: 42761.6680
# Epoch 011 | Train Loss: 46311.1914 | Val Loss: 42729.5703
# Epoch 012 | Train Loss: 46276.3242 | Val Loss: 42700.3633
# Epoch 013 | Train Loss: 46244.5117 | Val Loss: 42673.0391
# Epoch 014 | Train Loss: 46216.0820 | Val Loss: 42646.3398
# Epoch 015 | Train Loss: 46186.3516 | Val Loss: 42619.4922
# Epoch 016 | Train Loss: 46156.8281 | Val Loss: 42592.4453
# Epoch 017 | Train Loss: 46127.4023 | Val Loss: 42565.3008
# Epoch 018 | Train Loss: 46097.9180 | Val Loss: 42538.2031
# Epoch 019 | Train Loss: 46069.0000 | Val Loss: 42510.7852
# Epoch 020 | Train Loss: 46039.9766 | Val Loss: 42483.1875
# Epoch 021 | Train Loss: 46010.4062 | Val Loss: 42455.5078
# Epoch 022 | Train Loss: 45981.4961 | Val Loss: 42427.7305
# Epoch 023 | Train Loss: 45951.2812 | Val Loss: 42399.8555
# Epoch 024 | Train Loss: 45922.5312 | Val Loss: 42371.8398
# Epoch 025 | Train Loss: 45893.3750 | Val Loss: 42343.6289
# Epoch 026 | Train Loss: 45862.5781 | Val Loss: 42315.1562
# Epoch 027 | Train Loss: 45832.8828 | Val Loss: 42286.4297
# Epoch 028 | Train Loss: 45802.9609 | Val Loss: 42257.4648
# Epoch 029 | Train Loss: 45772.9648 | Val Loss: 42228.3086
# Epoch 030 | Train Loss: 45743.0469 | Val Loss: 42199.0000
# Epoch 031 | Train Loss: 45711.7148 | Val Loss: 42169.5312
# Epoch 032 | Train Loss: 45681.1133 | Val Loss: 42139.8945
# Epoch 033 | Train Loss: 45650.6875 | Val Loss: 42110.0664
# Epoch 034 | Train Loss: 45619.0547 | Val Loss: 42080.0000
# Epoch 035 | Train Loss: 45588.5742 | Val Loss: 42049.6875
# Epoch 036 | Train Loss: 45556.7734 | Val Loss: 42019.1133
# Epoch 037 | Train Loss: 45525.3867 | Val Loss: 41988.2930
# Epoch 038 | Train Loss: 45493.3945 | Val Loss: 41957.2461
# Epoch 039 | Train Loss: 45461.6758 | Val Loss: 41925.9922
# Epoch 040 | Train Loss: 45428.8359 | Val Loss: 41894.5586
# Epoch 041 | Train Loss: 45396.5195 | Val Loss: 41862.9570
# Epoch 042 | Train Loss: 45363.9297 | Val Loss: 41831.1484
# Epoch 043 | Train Loss: 45330.7422 | Val Loss: 41799.1406
# Epoch 044 | Train Loss: 45298.4375 | Val Loss: 41766.9023
# Epoch 045 | Train Loss: 45264.2695 | Val Loss: 41734.4336
# Epoch 046 | Train Loss: 45231.0312 | Val Loss: 41701.7812
# Epoch 047 | Train Loss: 45196.4219 | Val Loss: 41668.9062
# Epoch 048 | Train Loss: 45162.9570 | Val Loss: 41635.7812
# Epoch 049 | Train Loss: 45128.2344 | Val Loss: 41602.4062
# Epoch 050 | Train Loss: 45093.9102 | Val Loss: 41568.8164
# Epoch 051 | Train Loss: 45059.3086 | Val Loss: 41534.9922
# Epoch 052 | Train Loss: 45024.0391 | Val Loss: 41500.9805
# Epoch 053 | Train Loss: 44988.7812 | Val Loss: 41466.7930
# Epoch 054 | Train Loss: 44953.6523 | Val Loss: 41432.3477
# Epoch 055 | Train Loss: 44918.1406 | Val Loss: 41397.6367
# Epoch 056 | Train Loss: 44882.3164 | Val Loss: 41362.7266
# Epoch 057 | Train Loss: 44846.1797 | Val Loss: 41327.6250
# Epoch 058 | Train Loss: 44809.3906 | Val Loss: 41292.3203
# Epoch 059 | Train Loss: 44772.1797 | Val Loss: 41256.8008
# Epoch 060 | Train Loss: 44736.3555 | Val Loss: 41220.9922
# Epoch 061 | Train Loss: 44699.5000 | Val Loss: 41184.9570
# Epoch 062 | Train Loss: 44662.0273 | Val Loss: 41148.7070
# Epoch 063 | Train Loss: 44624.4922 | Val Loss: 41112.3125
# Epoch 064 | Train Loss: 44587.3047 | Val Loss: 41075.6797
# Epoch 065 | Train Loss: 44548.6328 | Val Loss: 41038.7812
# Epoch 066 | Train Loss: 44510.1445 | Val Loss: 41001.6641
# Epoch 067 | Train Loss: 44471.9961 | Val Loss: 40964.3828
# Epoch 068 | Train Loss: 44433.5547 | Val Loss: 40926.8438
# Epoch 069 | Train Loss: 44394.9180 | Val Loss: 40888.9883
# Epoch 070 | Train Loss: 44355.9297 | Val Loss: 40850.9453
# Epoch 071 | Train Loss: 44316.4023 | Val Loss: 40812.7969
# Epoch 072 | Train Loss: 44276.4688 | Val Loss: 40774.4688
# Epoch 073 | Train Loss: 44236.4766 | Val Loss: 40735.8828
# Epoch 074 | Train Loss: 44196.7539 | Val Loss: 40697.0195
# Epoch 075 | Train Loss: 44156.5898 | Val Loss: 40657.9219
# Epoch 076 | Train Loss: 44116.4023 | Val Loss: 40618.6523
# Epoch 077 | Train Loss: 44075.6602 | Val Loss: 40579.1602
# Epoch 078 | Train Loss: 44034.8047 | Val Loss: 40539.4336
# Epoch 079 | Train Loss: 43993.9258 | Val Loss: 40499.5742
# Epoch 080 | Train Loss: 43952.7812 | Val Loss: 40459.4336
# Epoch 081 | Train Loss: 43910.5000 | Val Loss: 40419.0508
# Epoch 082 | Train Loss: 43868.5352 | Val Loss: 40378.4453
# Epoch 083 | Train Loss: 43827.1016 | Val Loss: 40337.6367
# Epoch 084 | Train Loss: 43784.8242 | Val Loss: 40296.6133
# Epoch 085 | Train Loss: 43743.3125 | Val Loss: 40255.3750
# Epoch 086 | Train Loss: 43699.6133 | Val Loss: 40213.9375
# Epoch 087 | Train Loss: 43656.3281 | Val Loss: 40172.3359
# Epoch 088 | Train Loss: 43613.6758 | Val Loss: 40130.4648
# Epoch 089 | Train Loss: 43570.5156 | Val Loss: 40088.4414
# Epoch 090 | Train Loss: 43527.1602 | Val Loss: 40046.3086
# Epoch 091 | Train Loss: 43483.3203 | Val Loss: 40003.8672
# Epoch 092 | Train Loss: 43439.7578 | Val Loss: 39961.0547
# Epoch 093 | Train Loss: 43395.2188 | Val Loss: 39918.1484
# Epoch 094 | Train Loss: 43351.0742 | Val Loss: 39875.1133
# Epoch 095 | Train Loss: 43306.1328 | Val Loss: 39831.9453
# Epoch 096 | Train Loss: 43261.7773 | Val Loss: 39788.6602
# Epoch 097 | Train Loss: 43216.4766 | Val Loss: 39744.9648
# Epoch 098 | Train Loss: 43171.2617 | Val Loss: 39700.9023
# Epoch 099 | Train Loss: 43125.1758 | Val Loss: 39656.6602
# Epoch 100 | Train Loss: 43080.7109 | Val Loss: 39612.2734
# Epoch 101 | Train Loss: 43034.9219 | Val Loss: 39567.8125
# Epoch 102 | Train Loss: 42988.1797 | Val Loss: 39523.3750
# Epoch 103 | Train Loss: 42942.6484 | Val Loss: 39478.4609
# Epoch 104 | Train Loss: 42896.3086 | Val Loss: 39433.1055
# Epoch 105 | Train Loss: 42849.0859 | Val Loss: 39387.7891
# Epoch 106 | Train Loss: 42802.1562 | Val Loss: 39342.3164
# Epoch 107 | Train Loss: 42755.3359 | Val Loss: 39296.6914
# Epoch 108 | Train Loss: 42707.7734 | Val Loss: 39250.7305
# Epoch 109 | Train Loss: 42661.0312 | Val Loss: 39204.8398
# Epoch 110 | Train Loss: 42613.1328 | Val Loss: 39158.7148
# Epoch 111 | Train Loss: 42565.2305 | Val Loss: 39112.1484
# Epoch 112 | Train Loss: 42517.0742 | Val Loss: 39065.3008
# Epoch 113 | Train Loss: 42468.7031 | Val Loss: 39018.4688
# Epoch 114 | Train Loss: 42419.8359 | Val Loss: 38971.5547
# Epoch 115 | Train Loss: 42371.5391 | Val Loss: 38924.3438
# Epoch 116 | Train Loss: 42322.1250 | Val Loss: 38876.8203
# Epoch 117 | Train Loss: 42273.6641 | Val Loss: 38828.9180
# Epoch 118 | Train Loss: 42224.2500 | Val Loss: 38781.2852
# Epoch 119 | Train Loss: 42174.6367 | Val Loss: 38733.2500
# Epoch 120 | Train Loss: 42124.4961 | Val Loss: 38685.3164
# Epoch 121 | Train Loss: 42075.1016 | Val Loss: 38637.3867
# Epoch 122 | Train Loss: 42024.6641 | Val Loss: 38588.2109
# Epoch 123 | Train Loss: 41974.9062 | Val Loss: 38539.3047
# Epoch 124 | Train Loss: 41923.9492 | Val Loss: 38490.3203
# Epoch 125 | Train Loss: 41874.0430 | Val Loss: 38441.5469
# Epoch 126 | Train Loss: 41822.2617 | Val Loss: 38392.2852
# Epoch 127 | Train Loss: 41771.7773 | Val Loss: 38342.7852
# Epoch 128 | Train Loss: 41720.0039 | Val Loss: 38293.2734
# Epoch 129 | Train Loss: 41669.3789 | Val Loss: 38243.1250
# Epoch 130 | Train Loss: 41618.1016 | Val Loss: 38193.1992
# Epoch 131 | Train Loss: 41565.7227 | Val Loss: 38143.0391
# Epoch 132 | Train Loss: 41513.9453 | Val Loss: 38092.3438
# Epoch 133 | Train Loss: 41460.9570 | Val Loss: 38042.0156
# Epoch 134 | Train Loss: 41409.3320 | Val Loss: 37991.2461
# Epoch 135 | Train Loss: 41356.6133 | Val Loss: 37940.3906
# Epoch 136 | Train Loss: 41303.7188 | Val Loss: 37889.2695
# Epoch 137 | Train Loss: 41250.3789 | Val Loss: 37837.9531
# Epoch 138 | Train Loss: 41197.6523 | Val Loss: 37786.8008
# Epoch 139 | Train Loss: 41143.9961 | Val Loss: 37735.1289
# Epoch 140 | Train Loss: 41091.3438 | Val Loss: 37683.0781
# Epoch 141 | Train Loss: 41037.2539 | Val Loss: 37631.1680
# Epoch 142 | Train Loss: 40983.7812 | Val Loss: 37579.1289
# Epoch 143 | Train Loss: 40929.5781 | Val Loss: 37527.3633
# Epoch 144 | Train Loss: 40875.4922 | Val Loss: 37474.8477
# Epoch 145 | Train Loss: 40821.2852 | Val Loss: 37422.1641
# Epoch 146 | Train Loss: 40766.5078 | Val Loss: 37369.3125
# Epoch 147 | Train Loss: 40712.3555 | Val Loss: 37316.5312
# Epoch 148 | Train Loss: 40657.0742 | Val Loss: 37264.0078
# Epoch 149 | Train Loss: 40602.0938 | Val Loss: 37210.5273
# Epoch 150 | Train Loss: 40547.5938 | Val Loss: 37157.0391
# Epoch 151 | Train Loss: 40491.4883 | Val Loss: 37103.1602
# Epoch 152 | Train Loss: 40436.2891 | Val Loss: 37049.4727
# Epoch 153 | Train Loss: 40380.4609 | Val Loss: 36995.8984
# Epoch 154 | Train Loss: 40324.0117 | Val Loss: 36942.5508
# Epoch 155 | Train Loss: 40269.1992 | Val Loss: 36888.2539
# Epoch 156 | Train Loss: 40212.5625 | Val Loss: 36833.6445
# Epoch 157 | Train Loss: 40156.5742 | Val Loss: 36779.1055
# Epoch 158 | Train Loss: 40100.4414 | Val Loss: 36724.9180
# Epoch 159 | Train Loss: 40043.0039 | Val Loss: 36670.4297
# Epoch 160 | Train Loss: 39987.0352 | Val Loss: 36615.3242
# Epoch 161 | Train Loss: 39929.1641 | Val Loss: 36559.7930
# Epoch 162 | Train Loss: 39872.0312 | Val Loss: 36504.4375
# Epoch 163 | Train Loss: 39815.4297 | Val Loss: 36449.4492
# Epoch 164 | Train Loss: 39757.6875 | Val Loss: 36394.5898
# Epoch 165 | Train Loss: 39700.3789 | Val Loss: 36338.5273
# Epoch 166 | Train Loss: 39642.2266 | Val Loss: 36282.2656
# Epoch 167 | Train Loss: 39584.4922 | Val Loss: 36226.3984
# Epoch 168 | Train Loss: 39526.7031 | Val Loss: 36171.0820
# Epoch 169 | Train Loss: 39469.2266 | Val Loss: 36115.4336
# Epoch 170 | Train Loss: 39410.5625 | Val Loss: 36058.7148
# Epoch 171 | Train Loss: 39352.1328 | Val Loss: 36001.6172
# Epoch 172 | Train Loss: 39293.2734 | Val Loss: 35945.3750
# Epoch 173 | Train Loss: 39235.3516 | Val Loss: 35888.3906
# Epoch 174 | Train Loss: 39176.3242 | Val Loss: 35831.7188
# Epoch 175 | Train Loss: 39116.8555 | Val Loss: 35775.0938
# Epoch 176 | Train Loss: 39057.5547 | Val Loss: 35717.6523
# Epoch 177 | Train Loss: 38997.9883 | Val Loss: 35660.0156
# Epoch 178 | Train Loss: 38938.8281 | Val Loss: 35603.2148
# Epoch 179 | Train Loss: 38879.7227 | Val Loss: 35545.7422
# Epoch 180 | Train Loss: 38819.5273 | Val Loss: 35488.2656
# Epoch 181 | Train Loss: 38759.8125 | Val Loss: 35430.0547
# Epoch 182 | Train Loss: 38699.8047 | Val Loss: 35372.1562
# Epoch 183 | Train Loss: 38640.1016 | Val Loss: 35313.8984
# Epoch 184 | Train Loss: 38579.6211 | Val Loss: 35256.3398
# Epoch 185 | Train Loss: 38519.3516 | Val Loss: 35198.1992
# Epoch 186 | Train Loss: 38458.8047 | Val Loss: 35139.1055
# Epoch 187 | Train Loss: 38398.5039 | Val Loss: 35080.9727
# Epoch 188 | Train Loss: 38338.1055 | Val Loss: 35021.9531
# Epoch 189 | Train Loss: 38276.7266 | Val Loss: 34964.3047
# Epoch 190 | Train Loss: 38216.7227 | Val Loss: 34904.0234
# Epoch 191 | Train Loss: 38154.1406 | Val Loss: 34845.5234
# Epoch 192 | Train Loss: 38094.1094 | Val Loss: 34786.6562
# Epoch 193 | Train Loss: 38031.9023 | Val Loss: 34727.7109
# Epoch 194 | Train Loss: 37970.4688 | Val Loss: 34667.7148
# Epoch 195 | Train Loss: 37908.4844 | Val Loss: 34608.3750
# Epoch 196 | Train Loss: 37847.1875 | Val Loss: 34548.4180
# Epoch 197 | Train Loss: 37785.8867 | Val Loss: 34488.8672
# Epoch 198 | Train Loss: 37723.2773 | Val Loss: 34429.7617
# Epoch 199 | Train Loss: 37661.5430 | Val Loss: 34370.2695
# Epoch 200 | Train Loss: 37598.7617 | Val Loss: 34309.4141
# Epoch 201 | Train Loss: 37536.3281 | Val Loss: 34249.0977
# Epoch 202 | Train Loss: 37475.0234 | Val Loss: 34188.3828
# Epoch 203 | Train Loss: 37412.2695 | Val Loss: 34129.0820
# Epoch 204 | Train Loss: 37349.8164 | Val Loss: 34068.9219
# Epoch 205 | Train Loss: 37287.0078 | Val Loss: 34007.4609
# Epoch 206 | Train Loss: 37224.1445 | Val Loss: 33946.8594
# Epoch 207 | Train Loss: 37160.7500 | Val Loss: 33886.2305
# Epoch 208 | Train Loss: 37098.2969 | Val Loss: 33825.7734
# Epoch 209 | Train Loss: 37035.0625 | Val Loss: 33764.3633
# Epoch 210 | Train Loss: 36971.0898 | Val Loss: 33702.8828
# Epoch 211 | Train Loss: 36907.5781 | Val Loss: 33642.4805
# Epoch 212 | Train Loss: 36844.6133 | Val Loss: 33580.6328
# Epoch 213 | Train Loss: 36781.1211 | Val Loss: 33518.9102
# Epoch 214 | Train Loss: 36717.2500 | Val Loss: 33457.7109
# Epoch 215 | Train Loss: 36653.2148 | Val Loss: 33397.2617
# Epoch 216 | Train Loss: 36589.2188 | Val Loss: 33334.3047
# Epoch 217 | Train Loss: 36525.1172 | Val Loss: 33272.1719
# Epoch 218 | Train Loss: 36460.7734 | Val Loss: 33211.3398
# Epoch 219 | Train Loss: 36397.0703 | Val Loss: 33149.3008
# Epoch 220 | Train Loss: 36332.6211 | Val Loss: 33086.4258
# Epoch 221 | Train Loss: 36268.4375 | Val Loss: 33024.5508
# Epoch 222 | Train Loss: 36203.2422 | Val Loss: 32962.7109
# Epoch 223 | Train Loss: 36138.7812 | Val Loss: 32900.7227
# Epoch 224 | Train Loss: 36073.8008 | Val Loss: 32837.8516
# Epoch 225 | Train Loss: 36009.6250 | Val Loss: 32775.6094
# Epoch 226 | Train Loss: 35944.7266 | Val Loss: 32712.4023
# Epoch 227 | Train Loss: 35879.4453 | Val Loss: 32650.3242
# Epoch 228 | Train Loss: 35814.4023 | Val Loss: 32587.1758
# Epoch 229 | Train Loss: 35749.1133 | Val Loss: 32524.4258
# Epoch 230 | Train Loss: 35683.8867 | Val Loss: 32461.0195
# Epoch 231 | Train Loss: 35618.4141 | Val Loss: 32398.3379
# Epoch 232 | Train Loss: 35553.0430 | Val Loss: 32335.2070
# Epoch 233 | Train Loss: 35487.4297 | Val Loss: 32272.4746
# Epoch 234 | Train Loss: 35421.7188 | Val Loss: 32209.0977
# Epoch 235 | Train Loss: 35355.8281 | Val Loss: 32145.1445
# Epoch 236 | Train Loss: 35290.2227 | Val Loss: 32082.1895
# Epoch 237 | Train Loss: 35224.5703 | Val Loss: 32018.7031
# Epoch 238 | Train Loss: 35157.8320 | Val Loss: 31955.3457
# Epoch 239 | Train Loss: 35091.9766 | Val Loss: 31891.3711
# Epoch 240 | Train Loss: 35027.2188 | Val Loss: 31827.5586
# Epoch 241 | Train Loss: 34959.6406 | Val Loss: 31763.7188
# Epoch 242 | Train Loss: 34893.6758 | Val Loss: 31700.3535
# Epoch 243 | Train Loss: 34828.0586 | Val Loss: 31636.1875
# Epoch 244 | Train Loss: 34761.4570 | Val Loss: 31571.8672
# Epoch 245 | Train Loss: 34694.2930 | Val Loss: 31508.0234
# Epoch 246 | Train Loss: 34628.2969 | Val Loss: 31443.5762
# Epoch 247 | Train Loss: 34561.8594 | Val Loss: 31378.9414
# Epoch 248 | Train Loss: 34494.3008 | Val Loss: 31315.1562
# Epoch 249 | Train Loss: 34428.1328 | Val Loss: 31250.7480
# Epoch 250 | Train Loss: 34360.8789 | Val Loss: 31186.0039
# Epoch 251 | Train Loss: 34293.3438 | Val Loss: 31122.1797
# Epoch 252 | Train Loss: 34227.1992 | Val Loss: 31056.9648
# Epoch 253 | Train Loss: 34159.6914 | Val Loss: 30992.7891
# Epoch 254 | Train Loss: 34092.4336 | Val Loss: 30928.1895
# Epoch 255 | Train Loss: 34025.5703 | Val Loss: 30863.3340
# Epoch 256 | Train Loss: 33957.4297 | Val Loss: 30798.1016
# Epoch 257 | Train Loss: 33890.5781 | Val Loss: 30733.3926
# Epoch 258 | Train Loss: 33824.0312 | Val Loss: 30668.3691
# Epoch 259 | Train Loss: 33755.1680 | Val Loss: 30603.3203
# Epoch 260 | Train Loss: 33687.4453 | Val Loss: 30538.2344
# Epoch 261 | Train Loss: 33620.5977 | Val Loss: 30472.8320
# Epoch 262 | Train Loss: 33551.8086 | Val Loss: 30408.7793
# Epoch 263 | Train Loss: 33485.2305 | Val Loss: 30342.6035
# Epoch 264 | Train Loss: 33417.0078 | Val Loss: 30277.3809
# Epoch 265 | Train Loss: 33349.0625 | Val Loss: 30212.8926
# Epoch 266 | Train Loss: 33281.4414 | Val Loss: 30147.1973
# Epoch 267 | Train Loss: 33213.5273 | Val Loss: 30080.8359
# Epoch 268 | Train Loss: 33145.4102 | Val Loss: 30015.3145
# Epoch 269 | Train Loss: 33077.0625 | Val Loss: 29951.0508
# Epoch 270 | Train Loss: 33009.3125 | Val Loss: 29884.5996
# Epoch 271 | Train Loss: 32940.7539 | Val Loss: 29819.0039
# Epoch 272 | Train Loss: 32873.0703 | Val Loss: 29753.5781
# Epoch 273 | Train Loss: 32804.4609 | Val Loss: 29688.3848
# Epoch 274 | Train Loss: 32736.5879 | Val Loss: 29621.7227
# Epoch 275 | Train Loss: 32667.2109 | Val Loss: 29555.4160
# Epoch 276 | Train Loss: 32598.2305 | Val Loss: 29490.4375
# Epoch 277 | Train Loss: 32531.0410 | Val Loss: 29423.9648
# Epoch 278 | Train Loss: 32461.5176 | Val Loss: 29358.1836
# Epoch 279 | Train Loss: 32393.0449 | Val Loss: 29292.6328
# Epoch 280 | Train Loss: 32324.8574 | Val Loss: 29226.1445
# Epoch 281 | Train Loss: 32255.9648 | Val Loss: 29159.8906
# Epoch 282 | Train Loss: 32187.0371 | Val Loss: 29094.0527
# Epoch 283 | Train Loss: 32119.3105 | Val Loss: 29028.1797
# Epoch 284 | Train Loss: 32049.7207 | Val Loss: 28962.0781
# Epoch 285 | Train Loss: 31981.2363 | Val Loss: 28895.7734
# Epoch 286 | Train Loss: 31912.4043 | Val Loss: 28829.2617
# Epoch 287 | Train Loss: 31842.8770 | Val Loss: 28762.6055
# Epoch 288 | Train Loss: 31773.6758 | Val Loss: 28696.0703
# Epoch 289 | Train Loss: 31704.9492 | Val Loss: 28630.0781
# Epoch 290 | Train Loss: 31635.1172 | Val Loss: 28562.6582
# Epoch 291 | Train Loss: 31566.1035 | Val Loss: 28496.5664
# Epoch 292 | Train Loss: 31497.3633 | Val Loss: 28430.2695
# Epoch 293 | Train Loss: 31427.8633 | Val Loss: 28363.8086
# Epoch 294 | Train Loss: 31357.9824 | Val Loss: 28296.7402
# Epoch 295 | Train Loss: 31289.0039 | Val Loss: 28230.3438
# Epoch 296 | Train Loss: 31220.0938 | Val Loss: 28163.6191
# Epoch 297 | Train Loss: 31150.2676 | Val Loss: 28096.6621
# Epoch 298 | Train Loss: 31081.1426 | Val Loss: 28030.5996
# Epoch 299 | Train Loss: 31011.6641 | Val Loss: 27963.4707
# Epoch 300 | Train Loss: 30942.3320 | Val Loss: 27896.8711
# Epoch 301 | Train Loss: 30872.4297 | Val Loss: 27830.0391
# Epoch 302 | Train Loss: 30803.1211 | Val Loss: 27763.4453
# Epoch 303 | Train Loss: 30733.5801 | Val Loss: 27696.3223
# Epoch 304 | Train Loss: 30664.1660 | Val Loss: 27629.8535
# Epoch 305 | Train Loss: 30594.4551 | Val Loss: 27562.6973
# Epoch 306 | Train Loss: 30525.3828 | Val Loss: 27496.0547
# Epoch 307 | Train Loss: 30455.4629 | Val Loss: 27429.4551
# Epoch 308 | Train Loss: 30385.2441 | Val Loss: 27362.0586
# Epoch 309 | Train Loss: 30315.8652 | Val Loss: 27295.0957
# Epoch 310 | Train Loss: 30246.2617 | Val Loss: 27228.4258
# Epoch 311 | Train Loss: 30176.8730 | Val Loss: 27161.8770
# Epoch 312 | Train Loss: 30107.3359 | Val Loss: 27094.2383
# Epoch 313 | Train Loss: 30037.2969 | Val Loss: 27026.9570
# Epoch 314 | Train Loss: 29966.5312 | Val Loss: 26959.9375
# Epoch 315 | Train Loss: 29897.4805 | Val Loss: 26893.5449
# Epoch 316 | Train Loss: 29827.3027 | Val Loss: 26825.9531
# Epoch 317 | Train Loss: 29757.3242 | Val Loss: 26759.2520
# Epoch 318 | Train Loss: 29688.4121 | Val Loss: 26692.4980
# Epoch 319 | Train Loss: 29617.7988 | Val Loss: 26625.0117
# Epoch 320 | Train Loss: 29547.6934 | Val Loss: 26557.9531
# Epoch 321 | Train Loss: 29478.3320 | Val Loss: 26490.7969
# Epoch 322 | Train Loss: 29408.4297 | Val Loss: 26423.4609
# Epoch 323 | Train Loss: 29338.2012 | Val Loss: 26356.7285
# Epoch 324 | Train Loss: 29268.9062 | Val Loss: 26289.2539
# Epoch 325 | Train Loss: 29198.5391 | Val Loss: 26222.2559
# Epoch 326 | Train Loss: 29128.5664 | Val Loss: 26155.1133
# Epoch 327 | Train Loss: 29058.8438 | Val Loss: 26088.4141
# Epoch 328 | Train Loss: 28988.2031 | Val Loss: 26020.6133
# Epoch 329 | Train Loss: 28917.9746 | Val Loss: 25953.8047
# Epoch 330 | Train Loss: 28848.7637 | Val Loss: 25886.6973
# Epoch 331 | Train Loss: 28778.4980 | Val Loss: 25819.6543
# Epoch 332 | Train Loss: 28708.7031 | Val Loss: 25752.2480
# Epoch 333 | Train Loss: 28638.1113 | Val Loss: 25685.5586
# Epoch 334 | Train Loss: 28568.8340 | Val Loss: 25617.8555
# Epoch 335 | Train Loss: 28498.6641 | Val Loss: 25551.1543
# Epoch 336 | Train Loss: 28428.4355 | Val Loss: 25483.8008
# Epoch 337 | Train Loss: 28358.5879 | Val Loss: 25416.8770
# Epoch 338 | Train Loss: 28288.4258 | Val Loss: 25349.4336
# Epoch 339 | Train Loss: 28218.1836 | Val Loss: 25282.9727
# Epoch 340 | Train Loss: 28148.3164 | Val Loss: 25215.1016
# Epoch 341 | Train Loss: 28077.9668 | Val Loss: 25147.8867
# Epoch 342 | Train Loss: 28008.1484 | Val Loss: 25081.3262
# Epoch 343 | Train Loss: 27938.6797 | Val Loss: 25014.2480
# Epoch 344 | Train Loss: 27868.2734 | Val Loss: 24946.5234
# Epoch 345 | Train Loss: 27798.3594 | Val Loss: 24880.2344
# Epoch 346 | Train Loss: 27728.5332 | Val Loss: 24813.2383
# Epoch 347 | Train Loss: 27658.8730 | Val Loss: 24745.9980
# Epoch 348 | Train Loss: 27588.7109 | Val Loss: 24678.7559
# Epoch 349 | Train Loss: 27518.8262 | Val Loss: 24611.2461
# Epoch 350 | Train Loss: 27448.3535 | Val Loss: 24545.3457
# Epoch 351 | Train Loss: 27379.3066 | Val Loss: 24477.3555
# Epoch 352 | Train Loss: 27308.6348 | Val Loss: 24411.0332
# Epoch 353 | Train Loss: 27239.6465 | Val Loss: 24343.7441
# Epoch 354 | Train Loss: 27168.8828 | Val Loss: 24276.7305
# Epoch 355 | Train Loss: 27099.2500 | Val Loss: 24210.0508
# Epoch 356 | Train Loss: 27029.6465 | Val Loss: 24142.7441
# Epoch 357 | Train Loss: 26959.0742 | Val Loss: 24076.1152
# Epoch 358 | Train Loss: 26889.5781 | Val Loss: 24009.2207
# Epoch 359 | Train Loss: 26820.0508 | Val Loss: 23942.2227
# Epoch 360 | Train Loss: 26749.6484 | Val Loss: 23875.8242
# Epoch 361 | Train Loss: 26680.5898 | Val Loss: 23809.5215
# Epoch 362 | Train Loss: 26611.4062 | Val Loss: 23743.3262
# Epoch 363 | Train Loss: 26541.9824 | Val Loss: 23675.8633
# Epoch 364 | Train Loss: 26471.7363 | Val Loss: 23609.3516
# Epoch 365 | Train Loss: 26401.6133 | Val Loss: 23542.3535
# Epoch 366 | Train Loss: 26331.9551 | Val Loss: 23476.0312
# Epoch 367 | Train Loss: 26262.6172 | Val Loss: 23408.8477
# Epoch 368 | Train Loss: 26192.4980 | Val Loss: 23342.3164
# Epoch 369 | Train Loss: 26123.3105 | Val Loss: 23275.3965
# Epoch 370 | Train Loss: 26053.3340 | Val Loss: 23209.8633
# Epoch 371 | Train Loss: 25984.1621 | Val Loss: 23142.2910
# Epoch 372 | Train Loss: 25914.4648 | Val Loss: 23075.5566
# Epoch 373 | Train Loss: 25844.8516 | Val Loss: 23009.8164
# Epoch 374 | Train Loss: 25775.3418 | Val Loss: 22942.6348
# Epoch 375 | Train Loss: 25705.4785 | Val Loss: 22876.4316
# Epoch 376 | Train Loss: 25636.8496 | Val Loss: 22811.2344
# Epoch 377 | Train Loss: 25567.8027 | Val Loss: 22744.9434
# Epoch 378 | Train Loss: 25498.9805 | Val Loss: 22678.3809
# Epoch 379 | Train Loss: 25429.3711 | Val Loss: 22611.4590
# Epoch 380 | Train Loss: 25359.9238 | Val Loss: 22545.5449
# Epoch 381 | Train Loss: 25290.1895 | Val Loss: 22479.6191
# Epoch 382 | Train Loss: 25221.2812 | Val Loss: 22412.5527
# Epoch 383 | Train Loss: 25152.1562 | Val Loss: 22347.3789
# Epoch 384 | Train Loss: 25082.9395 | Val Loss: 22280.8359
# Epoch 385 | Train Loss: 25013.7754 | Val Loss: 22215.5039
# Epoch 386 | Train Loss: 24945.1973 | Val Loss: 22148.4473
# Epoch 387 | Train Loss: 24875.4316 | Val Loss: 22082.6621
# Epoch 388 | Train Loss: 24806.7266 | Val Loss: 22017.1543
# Epoch 389 | Train Loss: 24737.7363 | Val Loss: 21950.9180
# Epoch 390 | Train Loss: 24668.5469 | Val Loss: 21884.9492
# Epoch 391 | Train Loss: 24599.7930 | Val Loss: 21819.3906
# Epoch 392 | Train Loss: 24530.9805 | Val Loss: 21753.9648
# Epoch 393 | Train Loss: 24462.1309 | Val Loss: 21687.9922
# Epoch 394 | Train Loss: 24393.3594 | Val Loss: 21622.0801
# Epoch 395 | Train Loss: 24324.7598 | Val Loss: 21556.8164
# Epoch 396 | Train Loss: 24256.3145 | Val Loss: 21491.3379
# Epoch 397 | Train Loss: 24187.6016 | Val Loss: 21425.6855
# Epoch 398 | Train Loss: 24119.3809 | Val Loss: 21360.6250
# Epoch 399 | Train Loss: 24050.7734 | Val Loss: 21295.0840
# Epoch 400 | Train Loss: 23982.6562 | Val Loss: 21229.6738
# Epoch 401 | Train Loss: 23914.1133 | Val Loss: 21164.7520
# Epoch 402 | Train Loss: 23845.5215 | Val Loss: 21099.5996
# Epoch 403 | Train Loss: 23777.9004 | Val Loss: 21034.8086
# Epoch 404 | Train Loss: 23709.6250 | Val Loss: 20969.0938
# Epoch 405 | Train Loss: 23640.7930 | Val Loss: 20904.2070
# Epoch 406 | Train Loss: 23573.1855 | Val Loss: 20839.6387
# Epoch 407 | Train Loss: 23505.3887 | Val Loss: 20774.4922
# Epoch 408 | Train Loss: 23437.2012 | Val Loss: 20709.7363
# Epoch 409 | Train Loss: 23369.1211 | Val Loss: 20644.7109
# Epoch 410 | Train Loss: 23301.1074 | Val Loss: 20579.8477
# Epoch 411 | Train Loss: 23232.9824 | Val Loss: 20515.1602
# Epoch 412 | Train Loss: 23165.3555 | Val Loss: 20450.4258
# Epoch 413 | Train Loss: 23097.9629 | Val Loss: 20386.4277
# Epoch 414 | Train Loss: 23030.2676 | Val Loss: 20321.5195
# Epoch 415 | Train Loss: 22962.8633 | Val Loss: 20257.6152
# Epoch 416 | Train Loss: 22895.4727 | Val Loss: 20192.5273
# Epoch 417 | Train Loss: 22827.8145 | Val Loss: 20128.4492
# Epoch 418 | Train Loss: 22760.1484 | Val Loss: 20064.3301
# Epoch 419 | Train Loss: 22692.6953 | Val Loss: 19999.5723
# Epoch 420 | Train Loss: 22625.4102 | Val Loss: 19936.2871
# Epoch 421 | Train Loss: 22558.5918 | Val Loss: 19872.4785
# Epoch 422 | Train Loss: 22491.9219 | Val Loss: 19807.9941
# Epoch 423 | Train Loss: 22424.1816 | Val Loss: 19744.1914
# Epoch 424 | Train Loss: 22357.3477 | Val Loss: 19680.2227
# Epoch 425 | Train Loss: 22290.1465 | Val Loss: 19616.4785
# Epoch 426 | Train Loss: 22223.5645 | Val Loss: 19552.6738
# Epoch 427 | Train Loss: 22156.3750 | Val Loss: 19489.0781
# Epoch 428 | Train Loss: 22089.8203 | Val Loss: 19425.7324
# Epoch 429 | Train Loss: 22023.4883 | Val Loss: 19362.0176
# Epoch 430 | Train Loss: 21956.3301 | Val Loss: 19298.7402
# Epoch 431 | Train Loss: 21889.9961 | Val Loss: 19235.2148
# Epoch 432 | Train Loss: 21823.6133 | Val Loss: 19172.3574
# Epoch 433 | Train Loss: 21757.4004 | Val Loss: 19109.2715
# Epoch 434 | Train Loss: 21691.2500 | Val Loss: 19046.1367
# Epoch 435 | Train Loss: 21624.7461 | Val Loss: 18982.4668
# Epoch 436 | Train Loss: 21558.3770 | Val Loss: 18920.6973
# Epoch 437 | Train Loss: 21493.1445 | Val Loss: 18857.3691
# Epoch 438 | Train Loss: 21426.7266 | Val Loss: 18794.8281
# Epoch 439 | Train Loss: 21360.9590 | Val Loss: 18731.8555
# Epoch 440 | Train Loss: 21294.9199 | Val Loss: 18669.3867
# Epoch 441 | Train Loss: 21229.1094 | Val Loss: 18606.8867
# Epoch 442 | Train Loss: 21164.0898 | Val Loss: 18543.9961
# Epoch 443 | Train Loss: 21097.7598 | Val Loss: 18481.8887
# Epoch 444 | Train Loss: 21031.9414 | Val Loss: 18419.4238
# Epoch 445 | Train Loss: 20967.1348 | Val Loss: 18357.0840
# Epoch 446 | Train Loss: 20901.3262 | Val Loss: 18294.9824
# Epoch 447 | Train Loss: 20835.5898 | Val Loss: 18232.4844
# Epoch 448 | Train Loss: 20770.7383 | Val Loss: 18170.9766
# Epoch 449 | Train Loss: 20705.3145 | Val Loss: 18108.8047
# Epoch 450 | Train Loss: 20640.0586 | Val Loss: 18046.6387
# Epoch 451 | Train Loss: 20575.1211 | Val Loss: 17985.3066
# Epoch 452 | Train Loss: 20510.4727 | Val Loss: 17923.3848
# Epoch 453 | Train Loss: 20445.6914 | Val Loss: 17861.9902
# Epoch 454 | Train Loss: 20380.8770 | Val Loss: 17800.7246
# Epoch 455 | Train Loss: 20316.3789 | Val Loss: 17739.4727
# Epoch 456 | Train Loss: 20251.9395 | Val Loss: 17678.0234
# Epoch 457 | Train Loss: 20187.4473 | Val Loss: 17616.7617
# Epoch 458 | Train Loss: 20122.9980 | Val Loss: 17555.8027
# Epoch 459 | Train Loss: 20058.6289 | Val Loss: 17494.6543
# Epoch 460 | Train Loss: 19994.4961 | Val Loss: 17433.7734
# Epoch 461 | Train Loss: 19930.3145 | Val Loss: 17373.0508
# Epoch 462 | Train Loss: 19866.6035 | Val Loss: 17312.1309
# Epoch 463 | Train Loss: 19802.3926 | Val Loss: 17251.4355
# Epoch 464 | Train Loss: 19738.7188 | Val Loss: 17190.8516
# Epoch 465 | Train Loss: 19674.7969 | Val Loss: 17130.3555
# Epoch 466 | Train Loss: 19611.1680 | Val Loss: 17070.7266
# Epoch 467 | Train Loss: 19548.1250 | Val Loss: 17010.0449
# Epoch 468 | Train Loss: 19484.7168 | Val Loss: 16949.7871
# Epoch 469 | Train Loss: 19421.0371 | Val Loss: 16890.2070
# Epoch 470 | Train Loss: 19358.0566 | Val Loss: 16829.7129
# Epoch 471 | Train Loss: 19294.3379 | Val Loss: 16769.6699
# Epoch 472 | Train Loss: 19231.6758 | Val Loss: 16710.7891
# Epoch 473 | Train Loss: 19168.7012 | Val Loss: 16650.3242
# Epoch 474 | Train Loss: 19105.6699 | Val Loss: 16590.9160
# Epoch 475 | Train Loss: 19043.1152 | Val Loss: 16531.6465
# Epoch 476 | Train Loss: 18980.6758 | Val Loss: 16472.2402
# Epoch 477 | Train Loss: 18918.1055 | Val Loss: 16412.8945
# Epoch 478 | Train Loss: 18855.4980 | Val Loss: 16353.8369
# Epoch 479 | Train Loss: 18792.8730 | Val Loss: 16294.6797
# Epoch 480 | Train Loss: 18731.1504 | Val Loss: 16235.5996
# Epoch 481 | Train Loss: 18668.5410 | Val Loss: 16176.7568
# Epoch 482 | Train Loss: 18606.3457 | Val Loss: 16117.7920
# Epoch 483 | Train Loss: 18544.2051 | Val Loss: 16059.5605
# Epoch 484 | Train Loss: 18482.6875 | Val Loss: 16001.0547
# Epoch 485 | Train Loss: 18421.1191 | Val Loss: 15942.6191
# Epoch 486 | Train Loss: 18359.4180 | Val Loss: 15883.9766
# Epoch 487 | Train Loss: 18297.6641 | Val Loss: 15826.0176
# Epoch 488 | Train Loss: 18236.7109 | Val Loss: 15767.7842
# Epoch 489 | Train Loss: 18175.1133 | Val Loss: 15710.2471
# Epoch 490 | Train Loss: 18114.1094 | Val Loss: 15652.2617
# Epoch 491 | Train Loss: 18053.2734 | Val Loss: 15594.6953
# Epoch 492 | Train Loss: 17992.2695 | Val Loss: 15536.4199
# Epoch 493 | Train Loss: 17931.0781 | Val Loss: 15479.0762
# Epoch 494 | Train Loss: 17870.3535 | Val Loss: 15421.5840
# Epoch 495 | Train Loss: 17809.6719 | Val Loss: 15364.1611
# Epoch 496 | Train Loss: 17749.0527 | Val Loss: 15307.3086
# Epoch 497 | Train Loss: 17688.6562 | Val Loss: 15249.8076
# Epoch 498 | Train Loss: 17628.3945 | Val Loss: 15192.8193
# Epoch 499 | Train Loss: 17568.2676 | Val Loss: 15136.6035
# Epoch 500 | Train Loss: 17508.3164 | Val Loss: 15079.5840
# Epoch 501 | Train Loss: 17448.5840 | Val Loss: 15023.6768
# Epoch 502 | Train Loss: 17389.1660 | Val Loss: 14966.8525
# Epoch 503 | Train Loss: 17329.5078 | Val Loss: 14910.5293
# Epoch 504 | Train Loss: 17269.6211 | Val Loss: 14853.4355
# Epoch 505 | Train Loss: 17209.6328 | Val Loss: 14797.4062
# Epoch 506 | Train Loss: 17150.3730 | Val Loss: 14741.7041
# Epoch 507 | Train Loss: 17091.1191 | Val Loss: 14685.3252
# Epoch 508 | Train Loss: 17032.1016 | Val Loss: 14630.2471
# Epoch 509 | Train Loss: 16973.1660 | Val Loss: 14574.1299
# Epoch 510 | Train Loss: 16914.0898 | Val Loss: 14518.0439
# Epoch 511 | Train Loss: 16855.0293 | Val Loss: 14462.9590
# Epoch 512 | Train Loss: 16796.4277 | Val Loss: 14407.3369
# Epoch 513 | Train Loss: 16737.4512 | Val Loss: 14352.0801
# Epoch 514 | Train Loss: 16679.2070 | Val Loss: 14297.0986
# Epoch 515 | Train Loss: 16620.8770 | Val Loss: 14242.1045
# Epoch 516 | Train Loss: 16562.5664 | Val Loss: 14187.0859
# Epoch 517 | Train Loss: 16504.5156 | Val Loss: 14132.5420
# Epoch 518 | Train Loss: 16446.9062 | Val Loss: 14078.0410
# Epoch 519 | Train Loss: 16389.0156 | Val Loss: 14023.3594
# Epoch 520 | Train Loss: 16331.1592 | Val Loss: 13969.0713
# Epoch 521 | Train Loss: 16273.3906 | Val Loss: 13914.8418
# Epoch 522 | Train Loss: 16216.2891 | Val Loss: 13860.2842
# Epoch 523 | Train Loss: 16158.4043 | Val Loss: 13806.6260
# Epoch 524 | Train Loss: 16101.3779 | Val Loss: 13752.9395
# Epoch 525 | Train Loss: 16044.3477 | Val Loss: 13698.8486
# Epoch 526 | Train Loss: 15987.4229 | Val Loss: 13645.3164
# Epoch 527 | Train Loss: 15930.4551 | Val Loss: 13591.7871
# Epoch 528 | Train Loss: 15873.8555 | Val Loss: 13538.4160
# Epoch 529 | Train Loss: 15817.3057 | Val Loss: 13484.9229
# Epoch 530 | Train Loss: 15760.4082 | Val Loss: 13431.9121
# Epoch 531 | Train Loss: 15704.1162 | Val Loss: 13379.0215
# Epoch 532 | Train Loss: 15647.8643 | Val Loss: 13325.7568
# Epoch 533 | Train Loss: 15591.7715 | Val Loss: 13273.0879
# Epoch 534 | Train Loss: 15535.8506 | Val Loss: 13220.5938
# Epoch 535 | Train Loss: 15480.0283 | Val Loss: 13167.9297
# Epoch 536 | Train Loss: 15424.2988 | Val Loss: 13115.7441
# Epoch 537 | Train Loss: 15368.9707 | Val Loss: 13063.7373
# Epoch 538 | Train Loss: 15313.4766 | Val Loss: 13011.6357
# Epoch 539 | Train Loss: 15258.1162 | Val Loss: 12959.2129
# Epoch 540 | Train Loss: 15202.8213 | Val Loss: 12907.4062
# Epoch 541 | Train Loss: 15147.5693 | Val Loss: 12855.9658
# Epoch 542 | Train Loss: 15093.0039 | Val Loss: 12804.3350
# Epoch 543 | Train Loss: 15038.2158 | Val Loss: 12752.6738
# Epoch 544 | Train Loss: 14983.1934 | Val Loss: 12701.2617
# Epoch 545 | Train Loss: 14928.5859 | Val Loss: 12650.6113
# Epoch 546 | Train Loss: 14874.5225 | Val Loss: 12599.2568
# Epoch 547 | Train Loss: 14820.0293 | Val Loss: 12548.3252
# Epoch 548 | Train Loss: 14765.9678 | Val Loss: 12497.2646
# Epoch 549 | Train Loss: 14711.8389 | Val Loss: 12446.9092
# Epoch 550 | Train Loss: 14658.0537 | Val Loss: 12396.2383
# Epoch 551 | Train Loss: 14604.1826 | Val Loss: 12345.8252
# Epoch 552 | Train Loss: 14550.4883 | Val Loss: 12295.5957
# Epoch 553 | Train Loss: 14497.2119 | Val Loss: 12245.3779
# Epoch 554 | Train Loss: 14443.9033 | Val Loss: 12195.8311
# Epoch 555 | Train Loss: 14390.7559 | Val Loss: 12145.4629
# Epoch 556 | Train Loss: 14337.5762 | Val Loss: 12095.8926
# Epoch 557 | Train Loss: 14284.8232 | Val Loss: 12046.5000
# Epoch 558 | Train Loss: 14231.9062 | Val Loss: 11996.7725
# Epoch 559 | Train Loss: 14179.4551 | Val Loss: 11947.8701
# Epoch 560 | Train Loss: 14126.9600 | Val Loss: 11898.2617
# Epoch 561 | Train Loss: 14074.1445 | Val Loss: 11849.3965
# Epoch 562 | Train Loss: 14022.0518 | Val Loss: 11800.6455
# Epoch 563 | Train Loss: 13970.3037 | Val Loss: 11751.6211
# Epoch 564 | Train Loss: 13918.0508 | Val Loss: 11702.9805
# Epoch 565 | Train Loss: 13866.1279 | Val Loss: 11654.7168
# Epoch 566 | Train Loss: 13814.5684 | Val Loss: 11606.1826
# Epoch 567 | Train Loss: 13762.9580 | Val Loss: 11557.9561
# Epoch 568 | Train Loss: 13711.6709 | Val Loss: 11509.9297
# Epoch 569 | Train Loss: 13660.2832 | Val Loss: 11462.1807
# Epoch 570 | Train Loss: 13609.2842 | Val Loss: 11414.2158
# Epoch 571 | Train Loss: 13558.0791 | Val Loss: 11366.5381
# Epoch 572 | Train Loss: 13507.3506 | Val Loss: 11318.9463
# Epoch 573 | Train Loss: 13456.6152 | Val Loss: 11271.7998
# Epoch 574 | Train Loss: 13405.9629 | Val Loss: 11224.4648
# Epoch 575 | Train Loss: 13355.6602 | Val Loss: 11177.5098
# Epoch 576 | Train Loss: 13305.5713 | Val Loss: 11130.6992
# Epoch 577 | Train Loss: 13255.5459 | Val Loss: 11083.7051
# Epoch 578 | Train Loss: 13205.4688 | Val Loss: 11037.0723
# Epoch 579 | Train Loss: 13155.5342 | Val Loss: 10990.5469
# Epoch 580 | Train Loss: 13106.0303 | Val Loss: 10944.1729
# Epoch 581 | Train Loss: 13056.3213 | Val Loss: 10897.9785
# Epoch 582 | Train Loss: 13006.9668 | Val Loss: 10851.9600
# Epoch 583 | Train Loss: 12957.8027 | Val Loss: 10805.9219
# Epoch 584 | Train Loss: 12908.5713 | Val Loss: 10760.0137
# Epoch 585 | Train Loss: 12859.4375 | Val Loss: 10714.2920
# Epoch 586 | Train Loss: 12810.4180 | Val Loss: 10668.8564
# Epoch 587 | Train Loss: 12761.9824 | Val Loss: 10623.4141
# Epoch 588 | Train Loss: 12713.3848 | Val Loss: 10578.3438
# Epoch 589 | Train Loss: 12664.9951 | Val Loss: 10532.9297
# Epoch 590 | Train Loss: 12616.6680 | Val Loss: 10488.1973
# Epoch 591 | Train Loss: 12568.7227 | Val Loss: 10443.1855
# Epoch 592 | Train Loss: 12520.5576 | Val Loss: 10398.5898
# Epoch 593 | Train Loss: 12472.6084 | Val Loss: 10354.1436
# Epoch 594 | Train Loss: 12425.0117 | Val Loss: 10309.5332
# Epoch 595 | Train Loss: 12377.5332 | Val Loss: 10265.7480
# Epoch 596 | Train Loss: 12330.2275 | Val Loss: 10221.3291
# Epoch 597 | Train Loss: 12282.9863 | Val Loss: 10177.6270
# Epoch 598 | Train Loss: 12235.7539 | Val Loss: 10133.6641
# Epoch 599 | Train Loss: 12188.8232 | Val Loss: 10090.1123
# Epoch 600 | Train Loss: 12142.1963 | Val Loss: 10046.7900
# Epoch 601 | Train Loss: 12095.4287 | Val Loss: 10003.1436
# Epoch 602 | Train Loss: 12048.9180 | Val Loss: 9959.9863
# Epoch 603 | Train Loss: 12002.4043 | Val Loss: 9916.9102
# Epoch 604 | Train Loss: 11956.2207 | Val Loss: 9873.9268
# Epoch 605 | Train Loss: 11910.3936 | Val Loss: 9831.3906
# Epoch 606 | Train Loss: 11864.4150 | Val Loss: 9788.4619
# Epoch 607 | Train Loss: 11818.5654 | Val Loss: 9745.9980
# Epoch 608 | Train Loss: 11772.7041 | Val Loss: 9703.9189
# Epoch 609 | Train Loss: 11727.3828 | Val Loss: 9661.5088
# Epoch 610 | Train Loss: 11681.9893 | Val Loss: 9619.3906
# Epoch 611 | Train Loss: 11636.7100 | Val Loss: 9577.6582
# Epoch 612 | Train Loss: 11591.9414 | Val Loss: 9535.8945
# Epoch 613 | Train Loss: 11546.9629 | Val Loss: 9494.2939
# Epoch 614 | Train Loss: 11502.2959 | Val Loss: 9452.9766
# Epoch 615 | Train Loss: 11457.6113 | Val Loss: 9411.5264
# Epoch 616 | Train Loss: 11413.3838 | Val Loss: 9370.5176
# Epoch 617 | Train Loss: 11369.0820 | Val Loss: 9329.4658
# Epoch 618 | Train Loss: 11324.9072 | Val Loss: 9288.3584
# Epoch 619 | Train Loss: 11281.0010 | Val Loss: 9248.0273
# Epoch 620 | Train Loss: 11237.2676 | Val Loss: 9207.0859
# Epoch 621 | Train Loss: 11193.2773 | Val Loss: 9166.7725
# Epoch 622 | Train Loss: 11149.7363 | Val Loss: 9126.5234
# Epoch 623 | Train Loss: 11106.4922 | Val Loss: 9086.2793
# Epoch 624 | Train Loss: 11063.3447 | Val Loss: 9046.3867
# Epoch 625 | Train Loss: 11020.0596 | Val Loss: 9006.5850
# Epoch 626 | Train Loss: 10976.9482 | Val Loss: 8966.8506
# Epoch 627 | Train Loss: 10934.5029 | Val Loss: 8927.1914
# Epoch 628 | Train Loss: 10891.6260 | Val Loss: 8887.8525
# Epoch 629 | Train Loss: 10849.0801 | Val Loss: 8848.6445
# Epoch 630 | Train Loss: 10806.9863 | Val Loss: 8809.3525
# Epoch 631 | Train Loss: 10764.4707 | Val Loss: 8770.4932
# Epoch 632 | Train Loss: 10722.4922 | Val Loss: 8731.7783
# Epoch 633 | Train Loss: 10680.9307 | Val Loss: 8693.3350
# Epoch 634 | Train Loss: 10639.0703 | Val Loss: 8654.5303
# Epoch 635 | Train Loss: 10597.4092 | Val Loss: 8616.2061
# Epoch 636 | Train Loss: 10555.9863 | Val Loss: 8577.9551
# Epoch 637 | Train Loss: 10514.5684 | Val Loss: 8539.9629
# Epoch 638 | Train Loss: 10473.6318 | Val Loss: 8501.8193
# Epoch 639 | Train Loss: 10432.3809 | Val Loss: 8464.1650
# Epoch 640 | Train Loss: 10391.7314 | Val Loss: 8426.5693
# Epoch 641 | Train Loss: 10350.9980 | Val Loss: 8388.9375
# Epoch 642 | Train Loss: 10310.3027 | Val Loss: 8351.6836
# Epoch 643 | Train Loss: 10270.0010 | Val Loss: 8314.4297
# Epoch 644 | Train Loss: 10229.7129 | Val Loss: 8277.6279
# Epoch 645 | Train Loss: 10189.6885 | Val Loss: 8240.5029
# Epoch 646 | Train Loss: 10149.6025 | Val Loss: 8203.7422
# Epoch 647 | Train Loss: 10109.7959 | Val Loss: 8167.2373
# Epoch 648 | Train Loss: 10070.2275 | Val Loss: 8130.7090
# Epoch 649 | Train Loss: 10030.7588 | Val Loss: 8094.5166
# Epoch 650 | Train Loss: 9991.2852 | Val Loss: 8058.2612
# Epoch 651 | Train Loss: 9952.0488 | Val Loss: 8022.2520
# Epoch 652 | Train Loss: 9913.1299 | Val Loss: 7986.3618
# Epoch 653 | Train Loss: 9874.1914 | Val Loss: 7950.8677
# Epoch 654 | Train Loss: 9835.6367 | Val Loss: 7915.0869
# Epoch 655 | Train Loss: 9796.8584 | Val Loss: 7879.7144
# Epoch 656 | Train Loss: 9758.4355 | Val Loss: 7844.4932
# Epoch 657 | Train Loss: 9720.1465 | Val Loss: 7809.5420
# Epoch 658 | Train Loss: 9682.1494 | Val Loss: 7774.1250
# Epoch 659 | Train Loss: 9643.9111 | Val Loss: 7739.3516
# Epoch 660 | Train Loss: 9606.0957 | Val Loss: 7704.8794
# Epoch 661 | Train Loss: 9568.5195 | Val Loss: 7670.2861
# Epoch 662 | Train Loss: 9530.9551 | Val Loss: 7635.7417
# Epoch 663 | Train Loss: 9493.5996 | Val Loss: 7601.5156
# Epoch 664 | Train Loss: 9456.0752 | Val Loss: 7567.5073
# Epoch 665 | Train Loss: 9419.0049 | Val Loss: 7533.3940
# Epoch 666 | Train Loss: 9382.1113 | Val Loss: 7499.5371
# Epoch 667 | Train Loss: 9345.3594 | Val Loss: 7466.0278
# Epoch 668 | Train Loss: 9308.5986 | Val Loss: 7432.5425
# Epoch 669 | Train Loss: 9272.1621 | Val Loss: 7398.9590
# Epoch 670 | Train Loss: 9235.5938 | Val Loss: 7365.7617
# Epoch 671 | Train Loss: 9199.5674 | Val Loss: 7332.8628
# Epoch 672 | Train Loss: 9163.5254 | Val Loss: 7299.8833
# Epoch 673 | Train Loss: 9127.6445 | Val Loss: 7267.0674
# Epoch 674 | Train Loss: 9091.7666 | Val Loss: 7234.3999
# Epoch 675 | Train Loss: 9056.2764 | Val Loss: 7202.0518
# Epoch 676 | Train Loss: 9020.8828 | Val Loss: 7169.7285
# Epoch 677 | Train Loss: 8985.7344 | Val Loss: 7137.3228
# Epoch 678 | Train Loss: 8950.3115 | Val Loss: 7105.2920
# Epoch 679 | Train Loss: 8915.3721 | Val Loss: 7073.3950
# Epoch 680 | Train Loss: 8880.3545 | Val Loss: 7041.7451
# Epoch 681 | Train Loss: 8845.7598 | Val Loss: 7009.8657
# Epoch 682 | Train Loss: 8811.1104 | Val Loss: 6978.4458
# Epoch 683 | Train Loss: 8776.5811 | Val Loss: 6947.0737
# Epoch 684 | Train Loss: 8742.2998 | Val Loss: 6915.9414
# Epoch 685 | Train Loss: 8708.3418 | Val Loss: 6884.9780
# Epoch 686 | Train Loss: 8674.3125 | Val Loss: 6853.9580
# Epoch 687 | Train Loss: 8640.4395 | Val Loss: 6823.0400
# Epoch 688 | Train Loss: 8606.6641 | Val Loss: 6792.7163
# Epoch 689 | Train Loss: 8573.3633 | Val Loss: 6762.1167
# Epoch 690 | Train Loss: 8539.7686 | Val Loss: 6731.5991
# Epoch 691 | Train Loss: 8506.4209 | Val Loss: 6701.6094
# Epoch 692 | Train Loss: 8473.5127 | Val Loss: 6671.5029
# Epoch 693 | Train Loss: 8440.4170 | Val Loss: 6641.4561
# Epoch 694 | Train Loss: 8407.6240 | Val Loss: 6611.7715
# Epoch 695 | Train Loss: 8374.9961 | Val Loss: 6582.0410
# Epoch 696 | Train Loss: 8342.2910 | Val Loss: 6552.5444
# Epoch 697 | Train Loss: 8310.0479 | Val Loss: 6523.2314
# Epoch 698 | Train Loss: 8277.7812 | Val Loss: 6494.0327
# Epoch 699 | Train Loss: 8245.6699 | Val Loss: 6464.9932
# Epoch 700 | Train Loss: 8213.7412 | Val Loss: 6436.0361
# Epoch 701 | Train Loss: 8181.9136 | Val Loss: 6407.2104
# Epoch 702 | Train Loss: 8150.2207 | Val Loss: 6378.6104
# Epoch 703 | Train Loss: 8118.6987 | Val Loss: 6350.1401
# Epoch 704 | Train Loss: 8087.4839 | Val Loss: 6321.8296
# Epoch 705 | Train Loss: 8056.1152 | Val Loss: 6293.5054
# Epoch 706 | Train Loss: 8025.0117 | Val Loss: 6265.4297
# Epoch 707 | Train Loss: 7994.1152 | Val Loss: 6237.5225
# Epoch 708 | Train Loss: 7963.3574 | Val Loss: 6209.6289
# Epoch 709 | Train Loss: 7932.6060 | Val Loss: 6182.0024
# Epoch 710 | Train Loss: 7902.1562 | Val Loss: 6154.5156
# Epoch 711 | Train Loss: 7871.9004 | Val Loss: 6127.0879
# Epoch 712 | Train Loss: 7841.5942 | Val Loss: 6099.8672
# Epoch 713 | Train Loss: 7811.5024 | Val Loss: 6072.7705
# Epoch 714 | Train Loss: 7781.5869 | Val Loss: 6045.7988
# Epoch 715 | Train Loss: 7751.7847 | Val Loss: 6018.9585
# Epoch 716 | Train Loss: 7722.1758 | Val Loss: 5992.3369
# Epoch 717 | Train Loss: 7692.6455 | Val Loss: 5965.6699
# Epoch 718 | Train Loss: 7663.3262 | Val Loss: 5939.2285
# Epoch 719 | Train Loss: 7633.9966 | Val Loss: 5912.9224
# Epoch 720 | Train Loss: 7604.8516 | Val Loss: 5886.8208
# Epoch 721 | Train Loss: 7575.9800 | Val Loss: 5860.7964
# Epoch 722 | Train Loss: 7547.2695 | Val Loss: 5834.8599
# Epoch 723 | Train Loss: 7518.4448 | Val Loss: 5809.1387
# Epoch 724 | Train Loss: 7490.0034 | Val Loss: 5783.5898
# Epoch 725 | Train Loss: 7461.5640 | Val Loss: 5758.1343
# Epoch 726 | Train Loss: 7433.2827 | Val Loss: 5732.7178
# Epoch 727 | Train Loss: 7405.1885 | Val Loss: 5707.5117
# Epoch 728 | Train Loss: 7377.2246 | Val Loss: 5682.4487
# Epoch 729 | Train Loss: 7349.4258 | Val Loss: 5657.5474
# Epoch 730 | Train Loss: 7321.7290 | Val Loss: 5632.6704
# Epoch 731 | Train Loss: 7294.1035 | Val Loss: 5608.0044
# Epoch 732 | Train Loss: 7266.6846 | Val Loss: 5583.4688
# Epoch 733 | Train Loss: 7239.3418 | Val Loss: 5559.0547
# Epoch 734 | Train Loss: 7212.2319 | Val Loss: 5534.7549
# Epoch 735 | Train Loss: 7185.2075 | Val Loss: 5510.6460
# Epoch 736 | Train Loss: 7158.3047 | Val Loss: 5486.5981
# Epoch 737 | Train Loss: 7131.6704 | Val Loss: 5462.7612
# Epoch 738 | Train Loss: 7105.0693 | Val Loss: 5438.9873
# Epoch 739 | Train Loss: 7078.5293 | Val Loss: 5415.3633
# Epoch 740 | Train Loss: 7052.2778 | Val Loss: 5391.9233
# Epoch 741 | Train Loss: 7026.0137 | Val Loss: 5368.5752
# Epoch 742 | Train Loss: 6999.9321 | Val Loss: 5345.3105
# Epoch 743 | Train Loss: 6974.0898 | Val Loss: 5322.2437
# Epoch 744 | Train Loss: 6948.2500 | Val Loss: 5299.2056
# Epoch 745 | Train Loss: 6922.5825 | Val Loss: 5276.4399
# Epoch 746 | Train Loss: 6897.0049 | Val Loss: 5253.7246
# Epoch 747 | Train Loss: 6871.7070 | Val Loss: 5231.0913
# Epoch 748 | Train Loss: 6846.3330 | Val Loss: 5208.6978
# Epoch 749 | Train Loss: 6821.2935 | Val Loss: 5186.3594
# Epoch 750 | Train Loss: 6796.3149 | Val Loss: 5164.1279
# Epoch 751 | Train Loss: 6771.4263 | Val Loss: 5142.1274
# Epoch 752 | Train Loss: 6746.7515 | Val Loss: 5120.1367
# Epoch 753 | Train Loss: 6722.0640 | Val Loss: 5098.3091
# Epoch 754 | Train Loss: 6697.6450 | Val Loss: 5076.6382
# Epoch 755 | Train Loss: 6673.2930 | Val Loss: 5055.0640
# Epoch 756 | Train Loss: 6648.9961 | Val Loss: 5033.6353
# Epoch 757 | Train Loss: 6624.9658 | Val Loss: 5012.2798
# Epoch 758 | Train Loss: 6601.1025 | Val Loss: 4991.1074
# Epoch 759 | Train Loss: 6577.1914 | Val Loss: 4970.0391
# Epoch 760 | Train Loss: 6553.5767 | Val Loss: 4949.1357
# Epoch 761 | Train Loss: 6529.9634 | Val Loss: 4928.2510
# Epoch 762 | Train Loss: 6506.5830 | Val Loss: 4907.5454
# Epoch 763 | Train Loss: 6483.2554 | Val Loss: 4887.0215
# Epoch 764 | Train Loss: 6460.0962 | Val Loss: 4866.5728
# Epoch 765 | Train Loss: 6437.0029 | Val Loss: 4846.1772
# Epoch 766 | Train Loss: 6414.1558 | Val Loss: 4825.9946
# Epoch 767 | Train Loss: 6391.2437 | Val Loss: 4805.9365
# Epoch 768 | Train Loss: 6368.6196 | Val Loss: 4785.9839
# Epoch 769 | Train Loss: 6346.0713 | Val Loss: 4766.1367
# Epoch 770 | Train Loss: 6323.6133 | Val Loss: 4746.3872
# Epoch 771 | Train Loss: 6301.3613 | Val Loss: 4726.7622
# Epoch 772 | Train Loss: 6279.1562 | Val Loss: 4707.3394
# Epoch 773 | Train Loss: 6257.1597 | Val Loss: 4687.9331
# Epoch 774 | Train Loss: 6235.2192 | Val Loss: 4668.6841
# Epoch 775 | Train Loss: 6213.4829 | Val Loss: 4649.6470
# Epoch 776 | Train Loss: 6191.8516 | Val Loss: 4630.5718
# Epoch 777 | Train Loss: 6170.2388 | Val Loss: 4611.6724
# Epoch 778 | Train Loss: 6148.8018 | Val Loss: 4592.9775
# Epoch 779 | Train Loss: 6127.5742 | Val Loss: 4574.3066
# Epoch 780 | Train Loss: 6106.3677 | Val Loss: 4555.7021
# Epoch 781 | Train Loss: 6085.2134 | Val Loss: 4537.3535
# Epoch 782 | Train Loss: 6064.3369 | Val Loss: 4518.9463
# Epoch 783 | Train Loss: 6043.5391 | Val Loss: 4500.7886
# Epoch 784 | Train Loss: 6022.8301 | Val Loss: 4482.8008
# Epoch 785 | Train Loss: 6002.2661 | Val Loss: 4464.7686
# Epoch 786 | Train Loss: 5981.8037 | Val Loss: 4446.8735
# Epoch 787 | Train Loss: 5961.4302 | Val Loss: 4429.2510
# Epoch 788 | Train Loss: 5941.2783 | Val Loss: 4411.5474
# Epoch 789 | Train Loss: 5921.1104 | Val Loss: 4394.0566
# Epoch 790 | Train Loss: 5901.1987 | Val Loss: 4376.6914
# Epoch 791 | Train Loss: 5881.2769 | Val Loss: 4359.4302
# Epoch 792 | Train Loss: 5861.5186 | Val Loss: 4342.1646
# Epoch 793 | Train Loss: 5841.9326 | Val Loss: 4325.1577
# Epoch 794 | Train Loss: 5822.3921 | Val Loss: 4308.2964
# Epoch 795 | Train Loss: 5803.0083 | Val Loss: 4291.3687
# Epoch 796 | Train Loss: 5783.6685 | Val Loss: 4274.6118
# Epoch 797 | Train Loss: 5764.5693 | Val Loss: 4258.0508
# Epoch 798 | Train Loss: 5745.4424 | Val Loss: 4241.5332
# Epoch 799 | Train Loss: 5726.5176 | Val Loss: 4225.1440
# Epoch 800 | Train Loss: 5707.7749 | Val Loss: 4208.8481
# Epoch 801 | Train Loss: 5689.0679 | Val Loss: 4192.6816
# Epoch 802 | Train Loss: 5670.4214 | Val Loss: 4176.5547
# Epoch 803 | Train Loss: 5651.9512 | Val Loss: 4160.6284
# Epoch 804 | Train Loss: 5633.6035 | Val Loss: 4144.8032
# Epoch 805 | Train Loss: 5615.4438 | Val Loss: 4128.9932
# Epoch 806 | Train Loss: 5597.2427 | Val Loss: 4113.3545
# Epoch 807 | Train Loss: 5579.1899 | Val Loss: 4097.8784
# Epoch 808 | Train Loss: 5561.3076 | Val Loss: 4082.4678
# Epoch 809 | Train Loss: 5543.5273 | Val Loss: 4067.1094
# Epoch 810 | Train Loss: 5525.7676 | Val Loss: 4051.8848
# Epoch 811 | Train Loss: 5508.1787 | Val Loss: 4036.7510
# Epoch 812 | Train Loss: 5490.7920 | Val Loss: 4021.7754
# Epoch 813 | Train Loss: 5473.4370 | Val Loss: 4006.8574
# Epoch 814 | Train Loss: 5456.0850 | Val Loss: 3992.0103
# Epoch 815 | Train Loss: 5438.9824 | Val Loss: 3977.2881
# Epoch 816 | Train Loss: 5421.8857 | Val Loss: 3962.7358
# Epoch 817 | Train Loss: 5404.9634 | Val Loss: 3948.2180
# Epoch 818 | Train Loss: 5388.1450 | Val Loss: 3933.8242
# Epoch 819 | Train Loss: 5371.4233 | Val Loss: 3919.5461
# Epoch 820 | Train Loss: 5354.8145 | Val Loss: 3905.3516
# Epoch 821 | Train Loss: 5338.3398 | Val Loss: 3891.2480
# Epoch 822 | Train Loss: 5321.9370 | Val Loss: 3877.2422
# Epoch 823 | Train Loss: 5305.5957 | Val Loss: 3863.3508
# Epoch 824 | Train Loss: 5289.3564 | Val Loss: 3849.5195
# Epoch 825 | Train Loss: 5273.2959 | Val Loss: 3835.8455
# Epoch 826 | Train Loss: 5257.3643 | Val Loss: 3822.2705
# Epoch 827 | Train Loss: 5241.4609 | Val Loss: 3808.7327
# Epoch 828 | Train Loss: 5225.6533 | Val Loss: 3795.3159
# Epoch 829 | Train Loss: 5210.0430 | Val Loss: 3782.0422
# Epoch 830 | Train Loss: 5194.4434 | Val Loss: 3768.8669
# Epoch 831 | Train Loss: 5179.0142 | Val Loss: 3755.6848
# Epoch 832 | Train Loss: 5163.5737 | Val Loss: 3742.6912
# Epoch 833 | Train Loss: 5148.3862 | Val Loss: 3729.7659
# Epoch 834 | Train Loss: 5133.1680 | Val Loss: 3716.9153
# ...
# Epoch 4721 | Train Loss: 3318.4795 | Val Loss: 2459.2612
# Epoch 4722 | Train Loss: 3319.5881 | Val Loss: 2459.3672
# Epoch 4723 | Train Loss: 3320.8662 | Val Loss: 2459.6274
# Epoch 4724 | Train Loss: 3318.9189 | Val Loss: 2459.5457
# Epoch 4725 | Train Loss: 3319.7544 | Val Loss: 2459.4348
# Epoch 4726 | Train Loss: 3319.5205 | Val Loss: 2459.1279
# Epoch 4727 | Train Loss: 3319.1877 | Val Loss: 2458.7256
# Epoch 4728 | Train Loss: 3319.5393 | Val Loss: 2458.4524
# Epoch 4729 | Train Loss: 3319.1343 | Val Loss: 2458.3594
# Epoch 4730 | Train Loss: 3319.8066 | Val Loss: 2458.4382
# Epoch 4731 | Train Loss: 3318.9949 | Val Loss: 2458.6052
# Epoch 4732 | Train Loss: 3319.6033 | Val Loss: 2458.8289
# Epoch 4733 | Train Loss: 3319.7793 | Val Loss: 2459.1648
# Epoch 4734 | Train Loss: 3319.8760 | Val Loss: 2459.5371
# Epoch 4735 | Train Loss: 3319.0261 | Val Loss: 2459.7896
# Epoch 4736 | Train Loss: 3320.0459 | Val Loss: 2460.1262
# Epoch 4737 | Train Loss: 3318.7832 | Val Loss: 2460.1389
# Epoch 4738 | Train Loss: 3320.6714 | Val Loss: 2460.1123
# Epoch 4739 | Train Loss: 3318.8782 | Val Loss: 2459.8994
# Epoch 4740 | Train Loss: 3319.0049 | Val Loss: 2459.5662
# Epoch 4741 | Train Loss: 3319.1233 | Val Loss: 2459.1064
# Epoch 4742 | Train Loss: 3319.2571 | Val Loss: 2458.7876
# Epoch 4743 | Train Loss: 3318.4526 | Val Loss: 2458.4221
# Epoch 4744 | Train Loss: 3319.1482 | Val Loss: 2458.0366
# Epoch 4745 | Train Loss: 3318.9189 | Val Loss: 2457.6440
# Epoch 4746 | Train Loss: 3320.1890 | Val Loss: 2457.2585
# Epoch 4747 | Train Loss: 3318.5664 | Val Loss: 2457.2288
# Epoch 4748 | Train Loss: 3320.1577 | Val Loss: 2458.4910
# Epoch 4749 | Train Loss: 3319.1602 | Val Loss: 2459.3247
# Epoch 4750 | Train Loss: 3320.3198 | Val Loss: 2460.1802
# Epoch 4751 | Train Loss: 3319.8552 | Val Loss: 2460.7673
# Epoch 4752 | Train Loss: 3319.8999 | Val Loss: 2461.0906
# Epoch 4753 | Train Loss: 3319.9775 | Val Loss: 2461.7646
# Epoch 4754 | Train Loss: 3319.7825 | Val Loss: 2461.9807
# Epoch 4755 | Train Loss: 3319.2666 | Val Loss: 2461.8774
# Epoch 4756 | Train Loss: 3319.5654 | Val Loss: 2461.8279
# Epoch 4757 | Train Loss: 3319.0791 | Val Loss: 2461.1294
# Epoch 4758 | Train Loss: 3319.6824 | Val Loss: 2460.6382
# Epoch 4759 | Train Loss: 3319.6763 | Val Loss: 2459.9792
# Epoch 4760 | Train Loss: 3319.6709 | Val Loss: 2459.2742
# Epoch 4761 | Train Loss: 3319.7222 | Val Loss: 2458.6619
# Epoch 4762 | Train Loss: 3319.6479 | Val Loss: 2458.1282
# Epoch 4763 | Train Loss: 3319.2354 | Val Loss: 2457.8931
# Epoch 4764 | Train Loss: 3318.6904 | Val Loss: 2457.4717
# Epoch 4765 | Train Loss: 3320.7490 | Val Loss: 2458.1128
# Epoch 4766 | Train Loss: 3319.4336 | Val Loss: 2458.6802
# Epoch 4767 | Train Loss: 3320.1592 | Val Loss: 2459.4395
# Epoch 4768 | Train Loss: 3318.5435 | Val Loss: 2459.9202
# Epoch 4769 | Train Loss: 3319.0413 | Val Loss: 2460.1555
# Epoch 4770 | Train Loss: 3319.5647 | Val Loss: 2460.2725
# Epoch 4771 | Train Loss: 3319.3542 | Val Loss: 2460.1040
# Epoch 4772 | Train Loss: 3319.8921 | Val Loss: 2459.7664
# Epoch 4773 | Train Loss: 3319.4556 | Val Loss: 2459.2510
# Epoch 4774 | Train Loss: 3319.9495 | Val Loss: 2458.7935
# Epoch 4775 | Train Loss: 3318.6167 | Val Loss: 2458.1907
# Epoch 4776 | Train Loss: 3319.4133 | Val Loss: 2457.6924
# Epoch 4777 | Train Loss: 3318.1580 | Val Loss: 2457.0745
# Epoch 4778 | Train Loss: 3319.7939 | Val Loss: 2456.9072
# Epoch 4779 | Train Loss: 3318.8828 | Val Loss: 2457.0186
# Epoch 4780 | Train Loss: 3319.6509 | Val Loss: 2457.2712
# Epoch 4781 | Train Loss: 3319.1216 | Val Loss: 2457.6279
# Epoch 4782 | Train Loss: 3319.4475 | Val Loss: 2458.2659
# Epoch 4783 | Train Loss: 3319.4546 | Val Loss: 2458.9009
# Epoch 4784 | Train Loss: 3319.5132 | Val Loss: 2459.3889
# Epoch 4785 | Train Loss: 3319.4700 | Val Loss: 2459.6230
# Epoch 4786 | Train Loss: 3318.9456 | Val Loss: 2459.6396
# Epoch 4787 | Train Loss: 3319.3384 | Val Loss: 2459.5762
# Epoch 4788 | Train Loss: 3318.7053 | Val Loss: 2459.2737
# Epoch 4789 | Train Loss: 3319.2246 | Val Loss: 2459.0642
# Epoch 4790 | Train Loss: 3319.2168 | Val Loss: 2458.8479
# Epoch 4791 | Train Loss: 3319.8369 | Val Loss: 2458.7388
# Epoch 4792 | Train Loss: 3318.7122 | Val Loss: 2458.4204
# Epoch 4793 | Train Loss: 3318.8552 | Val Loss: 2458.0388
# Epoch 4794 | Train Loss: 3319.3860 | Val Loss: 2457.7588
# Epoch 4795 | Train Loss: 3319.6909 | Val Loss: 2457.6252
# Epoch 4796 | Train Loss: 3319.0190 | Val Loss: 2457.5962
# Epoch 4797 | Train Loss: 3319.7725 | Val Loss: 2457.6421
# Epoch 4798 | Train Loss: 3319.2009 | Val Loss: 2457.6750
# Epoch 4799 | Train Loss: 3321.0459 | Val Loss: 2458.1167
# Epoch 4800 | Train Loss: 3319.2952 | Val Loss: 2458.5396
# Epoch 4801 | Train Loss: 3318.9373 | Val Loss: 2458.6001
# Epoch 4802 | Train Loss: 3320.1270 | Val Loss: 2458.9797
# Epoch 4803 | Train Loss: 3319.2090 | Val Loss: 2459.1892
# Epoch 4804 | Train Loss: 3320.1541 | Val Loss: 2459.4614
# Epoch 4805 | Train Loss: 3319.9106 | Val Loss: 2459.8142
# Epoch 4806 | Train Loss: 3319.9385 | Val Loss: 2460.1316
# Epoch 4807 | Train Loss: 3318.8896 | Val Loss: 2460.0186
# Epoch 4808 | Train Loss: 3320.2825 | Val Loss: 2459.9509
# Epoch 4809 | Train Loss: 3319.3911 | Val Loss: 2459.7642
# Epoch 4810 | Train Loss: 3319.8694 | Val Loss: 2459.5774
# Epoch 4811 | Train Loss: 3318.8757 | Val Loss: 2459.2544
# Epoch 4812 | Train Loss: 3320.1648 | Val Loss: 2458.9912
# Epoch 4813 | Train Loss: 3319.0996 | Val Loss: 2458.8574
# Epoch 4814 | Train Loss: 3319.6277 | Val Loss: 2458.6748
# Epoch 4815 | Train Loss: 3318.9751 | Val Loss: 2458.5903
# Epoch 4816 | Train Loss: 3320.0298 | Val Loss: 2458.6677
# Epoch 4817 | Train Loss: 3318.8943 | Val Loss: 2458.6428
# Epoch 4818 | Train Loss: 3320.3301 | Val Loss: 2458.7344
# Epoch 4819 | Train Loss: 3319.2219 | Val Loss: 2458.7727
# Epoch 4820 | Train Loss: 3318.9265 | Val Loss: 2458.6765
# Epoch 4821 | Train Loss: 3319.5989 | Val Loss: 2458.5256
# Epoch 4822 | Train Loss: 3318.6926 | Val Loss: 2458.2007
# Epoch 4823 | Train Loss: 3319.2659 | Val Loss: 2457.8745
# Epoch 4824 | Train Loss: 3319.7551 | Val Loss: 2457.8113
# Epoch 4825 | Train Loss: 3319.9863 | Val Loss: 2457.9236
# Epoch 4826 | Train Loss: 3318.6890 | Val Loss: 2458.0449
# Epoch 4827 | Train Loss: 3318.7358 | Val Loss: 2458.0601
# Epoch 4828 | Train Loss: 3318.4302 | Val Loss: 2458.0676
# Epoch 4829 | Train Loss: 3319.3787 | Val Loss: 2458.1157
# Epoch 4830 | Train Loss: 3319.9617 | Val Loss: 2458.2661
# Epoch 4831 | Train Loss: 3319.4006 | Val Loss: 2458.4070
# Epoch 4832 | Train Loss: 3319.7688 | Val Loss: 2458.4878
# Epoch 4833 | Train Loss: 3319.4485 | Val Loss: 2458.6626
# Epoch 4834 | Train Loss: 3318.9929 | Val Loss: 2458.8137
# Epoch 4835 | Train Loss: 3319.6985 | Val Loss: 2458.9956
# Epoch 4836 | Train Loss: 3319.9729 | Val Loss: 2459.2424
# Epoch 4837 | Train Loss: 3318.8987 | Val Loss: 2459.3840
# Epoch 4838 | Train Loss: 3318.9238 | Val Loss: 2459.4033
# Epoch 4839 | Train Loss: 3320.1182 | Val Loss: 2459.5305
# Epoch 4840 | Train Loss: 3319.4836 | Val Loss: 2459.5142
# Epoch 4841 | Train Loss: 3319.0056 | Val Loss: 2459.3757
# Epoch 4842 | Train Loss: 3318.7803 | Val Loss: 2459.1226
# Epoch 4843 | Train Loss: 3318.5669 | Val Loss: 2458.7324
# Epoch 4844 | Train Loss: 3320.3076 | Val Loss: 2458.4902
# Epoch 4845 | Train Loss: 3318.7839 | Val Loss: 2458.1182
# Epoch 4846 | Train Loss: 3319.0798 | Val Loss: 2457.7278
# Epoch 4847 | Train Loss: 3318.8547 | Val Loss: 2457.4343
# Epoch 4848 | Train Loss: 3319.0688 | Val Loss: 2457.1914
# Epoch 4849 | Train Loss: 3319.2256 | Val Loss: 2457.0286
# Epoch 4850 | Train Loss: 3319.4258 | Val Loss: 2457.0996
# Epoch 4851 | Train Loss: 3318.9902 | Val Loss: 2457.2620
# Epoch 4852 | Train Loss: 3318.5481 | Val Loss: 2457.4673
# Epoch 4853 | Train Loss: 3319.4355 | Val Loss: 2457.7651
# Epoch 4854 | Train Loss: 3319.0266 | Val Loss: 2458.1213
# Epoch 4855 | Train Loss: 3319.5610 | Val Loss: 2458.7036
# Epoch 4856 | Train Loss: 3320.2141 | Val Loss: 2459.5134
# Epoch 4857 | Train Loss: 3318.5962 | Val Loss: 2460.1172
# Epoch 4858 | Train Loss: 3318.9219 | Val Loss: 2460.5056
# Epoch 4859 | Train Loss: 3319.2717 | Val Loss: 2460.6191
# Epoch 4860 | Train Loss: 3319.0303 | Val Loss: 2460.4243
# Epoch 4861 | Train Loss: 3319.8650 | Val Loss: 2460.2471
# Epoch 4862 | Train Loss: 3319.9197 | Val Loss: 2460.0100
# Epoch 4863 | Train Loss: 3319.2649 | Val Loss: 2459.6580
# Epoch 4864 | Train Loss: 3319.8862 | Val Loss: 2459.4031
# Epoch 4865 | Train Loss: 3319.2969 | Val Loss: 2459.1262
# Epoch 4866 | Train Loss: 3319.4802 | Val Loss: 2458.9683
# Epoch 4867 | Train Loss: 3319.8037 | Val Loss: 2458.9932
# Epoch 4868 | Train Loss: 3320.7068 | Val Loss: 2459.3984
# Epoch 4869 | Train Loss: 3320.0554 | Val Loss: 2459.7529
# Epoch 4870 | Train Loss: 3319.4561 | Val Loss: 2460.1111
# Epoch 4871 | Train Loss: 3319.8325 | Val Loss: 2460.4258
# Epoch 4872 | Train Loss: 3319.5383 | Val Loss: 2460.6885
# Epoch 4873 | Train Loss: 3319.0259 | Val Loss: 2460.7046
# Epoch 4874 | Train Loss: 3318.8748 | Val Loss: 2460.5059
# Epoch 4875 | Train Loss: 3319.3867 | Val Loss: 2460.2219
# Epoch 4876 | Train Loss: 3317.9893 | Val Loss: 2459.6440
# Epoch 4877 | Train Loss: 3320.0698 | Val Loss: 2459.1511
# Epoch 4878 | Train Loss: 3319.2869 | Val Loss: 2458.5217
# Epoch 4879 | Train Loss: 3319.3188 | Val Loss: 2457.9617
# Epoch 4880 | Train Loss: 3319.8503 | Val Loss: 2457.5906
# Epoch 4881 | Train Loss: 3319.7966 | Val Loss: 2457.4751
# Epoch 4882 | Train Loss: 3319.2729 | Val Loss: 2457.5083
# Epoch 4883 | Train Loss: 3319.5806 | Val Loss: 2457.7070
# Epoch 4884 | Train Loss: 3320.0801 | Val Loss: 2458.1450
# Epoch 4885 | Train Loss: 3319.4072 | Val Loss: 2458.6028
# Epoch 4886 | Train Loss: 3319.5366 | Val Loss: 2458.9646
# Epoch 4887 | Train Loss: 3319.2200 | Val Loss: 2459.2522
# Epoch 4888 | Train Loss: 3319.3015 | Val Loss: 2459.4858
# Epoch 4889 | Train Loss: 3319.2686 | Val Loss: 2459.5554
# Epoch 4890 | Train Loss: 3319.8442 | Val Loss: 2459.4932
# Epoch 4891 | Train Loss: 3318.5803 | Val Loss: 2459.3352
# Epoch 4892 | Train Loss: 3318.9316 | Val Loss: 2459.2180
# Epoch 4893 | Train Loss: 3320.2207 | Val Loss: 2459.2480
# Epoch 4894 | Train Loss: 3319.0969 | Val Loss: 2459.2271
# Epoch 4895 | Train Loss: 3319.5469 | Val Loss: 2459.0371
# Epoch 4896 | Train Loss: 3318.4507 | Val Loss: 2458.6802
# Epoch 4897 | Train Loss: 3318.4604 | Val Loss: 2458.2141
# Epoch 4898 | Train Loss: 3319.2017 | Val Loss: 2457.6833
# Epoch 4899 | Train Loss: 3320.2720 | Val Loss: 2457.4033
# Epoch 4900 | Train Loss: 3319.1570 | Val Loss: 2457.2393
# Epoch 4901 | Train Loss: 3319.7124 | Val Loss: 2457.3320
# Epoch 4902 | Train Loss: 3319.2146 | Val Loss: 2457.5701
# Epoch 4903 | Train Loss: 3319.8293 | Val Loss: 2457.8240
# Epoch 4904 | Train Loss: 3319.2693 | Val Loss: 2458.0806
# Epoch 4905 | Train Loss: 3319.5381 | Val Loss: 2458.4353
# Epoch 4906 | Train Loss: 3319.6914 | Val Loss: 2459.0000
# Epoch 4907 | Train Loss: 3318.8979 | Val Loss: 2459.3955
# Epoch 4908 | Train Loss: 3318.9036 | Val Loss: 2459.6240
# Epoch 4909 | Train Loss: 3318.9297 | Val Loss: 2459.6045
# Epoch 4910 | Train Loss: 3319.3713 | Val Loss: 2459.5308
# Epoch 4911 | Train Loss: 3318.7495 | Val Loss: 2459.2170
# Epoch 4912 | Train Loss: 3319.4341 | Val Loss: 2458.8940
# Epoch 4913 | Train Loss: 3319.2517 | Val Loss: 2458.6230
# Epoch 4914 | Train Loss: 3318.8899 | Val Loss: 2458.3325
# Epoch 4915 | Train Loss: 3319.5400 | Val Loss: 2458.1482
# Epoch 4916 | Train Loss: 3318.9758 | Val Loss: 2458.0505
# Epoch 4917 | Train Loss: 3319.3281 | Val Loss: 2458.0583
# Epoch 4918 | Train Loss: 3319.2705 | Val Loss: 2458.2686
# Epoch 4919 | Train Loss: 3318.7571 | Val Loss: 2458.4614
# Epoch 4920 | Train Loss: 3318.3274 | Val Loss: 2458.5015
# Epoch 4921 | Train Loss: 3318.8044 | Val Loss: 2458.5593
# Epoch 4922 | Train Loss: 3318.7490 | Val Loss: 2458.4382
# Epoch 4923 | Train Loss: 3319.2075 | Val Loss: 2458.3218
# Epoch 4924 | Train Loss: 3320.5132 | Val Loss: 2458.4756
# Epoch 4925 | Train Loss: 3318.9663 | Val Loss: 2458.7029
# Epoch 4926 | Train Loss: 3319.7771 | Val Loss: 2458.9441
# Epoch 4927 | Train Loss: 3318.8384 | Val Loss: 2458.9299
# Epoch 4928 | Train Loss: 3320.4561 | Val Loss: 2459.2437
# Epoch 4929 | Train Loss: 3318.6125 | Val Loss: 2459.4202
# Epoch 4930 | Train Loss: 3319.0303 | Val Loss: 2459.7329
# Epoch 4931 | Train Loss: 3319.1787 | Val Loss: 2459.9814
# Epoch 4932 | Train Loss: 3320.5642 | Val Loss: 2460.3796
# Epoch 4933 | Train Loss: 3318.9255 | Val Loss: 2460.5127
# Epoch 4934 | Train Loss: 3319.6960 | Val Loss: 2460.3848
# Epoch 4935 | Train Loss: 3319.6316 | Val Loss: 2459.9690
# Epoch 4936 | Train Loss: 3318.4636 | Val Loss: 2459.3752
# Epoch 4937 | Train Loss: 3318.8513 | Val Loss: 2458.7263
# Epoch 4938 | Train Loss: 3319.0063 | Val Loss: 2458.1448
# Epoch 4939 | Train Loss: 3319.3601 | Val Loss: 2457.7253
# Epoch 4940 | Train Loss: 3318.9016 | Val Loss: 2457.6040
# Epoch 4941 | Train Loss: 3319.6062 | Val Loss: 2457.7129
# Epoch 4942 | Train Loss: 3318.6292 | Val Loss: 2457.9155
# Epoch 4943 | Train Loss: 3319.1660 | Val Loss: 2457.8960
# Epoch 4944 | Train Loss: 3319.5430 | Val Loss: 2457.9966
# Epoch 4945 | Train Loss: 3318.7283 | Val Loss: 2458.1848
# Epoch 4946 | Train Loss: 3317.9026 | Val Loss: 2458.0474
# Epoch 4947 | Train Loss: 3319.3867 | Val Loss: 2458.1614
# Epoch 4948 | Train Loss: 3320.1624 | Val Loss: 2458.6216
# Epoch 4949 | Train Loss: 3318.7561 | Val Loss: 2458.9558
# Epoch 4950 | Train Loss: 3318.6135 | Val Loss: 2458.7424
# Epoch 4951 | Train Loss: 3319.9143 | Val Loss: 2458.6831
# Epoch 4952 | Train Loss: 3320.7322 | Val Loss: 2458.8010
# Epoch 4953 | Train Loss: 3319.7668 | Val Loss: 2459.0432
# Epoch 4954 | Train Loss: 3321.2646 | Val Loss: 2459.3921
# Epoch 4955 | Train Loss: 3318.5471 | Val Loss: 2459.4531
# Epoch 4956 | Train Loss: 3319.2739 | Val Loss: 2459.5303
# Epoch 4957 | Train Loss: 3320.6729 | Val Loss: 2459.7542
# Epoch 4958 | Train Loss: 3320.2839 | Val Loss: 2460.2495
# Epoch 4959 | Train Loss: 3319.9302 | Val Loss: 2460.6045
# Epoch 4960 | Train Loss: 3319.2969 | Val Loss: 2460.8445
# Epoch 4961 | Train Loss: 3319.2864 | Val Loss: 2460.8313
# Epoch 4962 | Train Loss: 3319.4751 | Val Loss: 2460.6499
# Epoch 4963 | Train Loss: 3319.0261 | Val Loss: 2460.0667
# Epoch 4964 | Train Loss: 3320.2451 | Val Loss: 2459.4446
# Epoch 4965 | Train Loss: 3318.6252 | Val Loss: 2458.7344
# Epoch 4966 | Train Loss: 3319.7490 | Val Loss: 2457.9651
# Epoch 4967 | Train Loss: 3319.3674 | Val Loss: 2457.3638
# Epoch 4968 | Train Loss: 3320.6482 | Val Loss: 2457.0945
# Epoch 4969 | Train Loss: 3319.3733 | Val Loss: 2456.7986
# Epoch 4970 | Train Loss: 3319.0867 | Val Loss: 2456.9170
# Epoch 4971 | Train Loss: 3319.3530 | Val Loss: 2457.3511
# Epoch 4972 | Train Loss: 3319.8220 | Val Loss: 2457.8611
# Epoch 4973 | Train Loss: 3318.5488 | Val Loss: 2458.2603
# Epoch 4974 | Train Loss: 3318.4055 | Val Loss: 2458.3765
# Epoch 4975 | Train Loss: 3319.4348 | Val Loss: 2458.4849
# Epoch 4976 | Train Loss: 3319.6294 | Val Loss: 2458.5564
# Epoch 4977 | Train Loss: 3319.3962 | Val Loss: 2458.6719
# Epoch 4978 | Train Loss: 3319.3596 | Val Loss: 2458.5791
# Epoch 4979 | Train Loss: 3319.6963 | Val Loss: 2458.6890
# Epoch 4980 | Train Loss: 3319.6223 | Val Loss: 2458.9209
# Epoch 4981 | Train Loss: 3319.3843 | Val Loss: 2459.2607
# Epoch 4982 | Train Loss: 3319.1060 | Val Loss: 2459.2378
# Epoch 4983 | Train Loss: 3318.9546 | Val Loss: 2459.1531
# Epoch 4984 | Train Loss: 3319.7388 | Val Loss: 2459.1995
# Epoch 4985 | Train Loss: 3320.0093 | Val Loss: 2459.1479
# Epoch 4986 | Train Loss: 3319.2258 | Val Loss: 2459.0569
# Epoch 4987 | Train Loss: 3319.1631 | Val Loss: 2458.6650
# Epoch 4988 | Train Loss: 3319.3003 | Val Loss: 2458.2605
# Epoch 4989 | Train Loss: 3320.9209 | Val Loss: 2458.2996
# Epoch 4990 | Train Loss: 3318.9834 | Val Loss: 2458.3787
# Epoch 4991 | Train Loss: 3318.6418 | Val Loss: 2458.3376
# Epoch 4992 | Train Loss: 3320.2742 | Val Loss: 2458.4043
# Epoch 4993 | Train Loss: 3319.8835 | Val Loss: 2458.7256
# Epoch 4994 | Train Loss: 3319.8218 | Val Loss: 2458.9978
# Epoch 4995 | Train Loss: 3319.3220 | Val Loss: 2459.3284
# Epoch 4996 | Train Loss: 3319.8359 | Val Loss: 2459.7043
# Epoch 4997 | Train Loss: 3319.0051 | Val Loss: 2459.8560
# Epoch 4998 | Train Loss: 3319.1536 | Val Loss: 2459.8293
# Epoch 4999 | Train Loss: 3319.0300 | Val Loss: 2459.5032
# Epoch 5000 | Train Loss: 3318.5842 | Val Loss: 2458.9270

# %% [markdown]
# ## Fourth step: diagnostic plots

# %%
# Loss curves
plt.figure(figsize=(10, 6))
plt.plot(np.arange(epochs), train_losses, label="Train")
plt.plot(np.arange(epochs), val_losses, label="Validation")
plt.yscale('log')
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.legend()
plt.grid()
plt.show()

# %%
#Comparing predicted T-P profiles vs true T-P profiles with residuals
substep = 10

#Converting tensors to numpy arrays if this isn't already done
if (type(test_inputs) != np.ndarray):
    test_inputs = test_inputs.numpy()
    test_outputs_T = test_outputs_T.numpy()
    test_outputs_P = test_outputs_P.numpy()

for test_idx, (test_input, test_output_T, test_output_P, pred_output_T) in enumerate(zip(test_inputs, test_outputs_T, test_outputs_P, Y_pred)):

    #Plotting
    if (test_idx % substep == 0):
        fig, (ax1, ax2) = plt.subplots(1, 2, figsize=[8, 6], sharey=True, gridspec_kw = {'width_ratios':[3, 1]})
        ax1.plot(test_output_T, np.log(test_output_P/1000), '.', linestyle='-', color='blue', linewidth=2)
        ax1.plot(pred_output_T, np.log(test_output_P/1000), color='green', linewidth=2)
        ax1.invert_yaxis()
        ax1.set_ylabel(r'log$_{10}$ Pressure (bar)')
        ax1.set_xlabel('Temperature (K)')
        ax2.plot(pred_output_T - test_output_T, np.log(test_output_P/1000), '.', linestyle='-', color='green', linewidth=2)
        ax2.set_xlabel('Residuals (K)')
        plt.suptitle(rf'H$_2$O : {test_input[0]} bar, CO$_2$ : {test_input[1]} bar, LoD : {test_input[2]:.0f} days, Obliquity : {test_input[3]} deg')
        plt.tight_layout()
        plt.show()
